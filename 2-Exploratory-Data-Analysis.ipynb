# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Introduction

# %% [markdown]
# After the data cleaning step where we put our data into a few standard formats, the next step is to take a look at the data and see if what we're looking at makes sense. Before applying any fancy algorithms, it's always important to explore the data first.
#
# When working with numerical data, some of the exploratory data analysis (EDA) techniques we can use include finding the average of the data set, the distribution of the data, the most common values, etc. The idea is the same when working with text data. We are going to find some more obvious patterns with EDA before identifying the hidden patterns with machines learning (ML) techniques. We are going to look at the following for each comedian:
#
# 1. **Most common words** - find these and create word clouds
# 2. **Size of vocabulary** - look number of unique words and also how quickly someone speaks
# 3. **Amount of profanity** - most common terms

# %% [markdown]
# ## Most Common Words

# %% [markdown]
# ### Analysis

# %%
# Read in the document-term matrix
import pandas as pd

data = pd.read_pickle('dtm.pkl')
data = data.transpose()

data
# Out:
# title           dfis should be assessed beyond financial performance  \
# 003                                                             0
# 006                                                             0
# 0088                                                            0
# 01                                                              0
# 016                                                             0
# ...                                                           ...
# zin                                                             0
# zinbpimb                                                        0
# zone                                                            0
# zones                                                           0
# zulkifleeabbas                                                  0
#
# title           bank pembangunan 2019 pretax profit jumps declares rm152m dividend  \
# 003                                                             0
# 006                                                             0
# 0088                                                            0
# 01                                                              0
# 016                                                             0
# ...                                                           ...
# zin                                                             0
# zinbpimb                                                        0
# zone                                                            0
# zones                                                           0
# zulkifleeabbas                                                  0
#
# title           as lockdowns ease a bronx nail salon plans a careful reopening  \
# 003                                                             0
# 006                                                             0
# 0088                                                            0
# 01                                                              0
# 016                                                             0
# ...                                                           ...
# zin                                                             0
# zinbpimb                                                        0
# zone                                                            0
# zones                                                           0
# zulkifleeabbas                                                  0
#
# title           us fed says working to broaden access to ppp facility beyond banks  \
# 003                                                             0
# 006                                                             0
# 0088                                                            0
# 01                                                              0
# 016                                                             0
# ...                                                           ...
# zin                                                             0
# zinbpimb                                                        0
# zone                                                            0
# zones                                                           0
# zulkifleeabbas                                                  0
#
# title           bank negara to ensure sufficient ringgit liquidity  \
# 003                                                             0
# 006                                                             0
# 0088                                                            0
# 01                                                              0
# 016                                                             0
# ...                                                           ...
# zin                                                             0
# zinbpimb                                                        0
# zone                                                            0
# zones                                                           0
# zulkifleeabbas                                                  0
#
# title           providing sme support in times of need  \
# 003                                                  0
# 006                                                  0
# 0088                                                 1
# 01                                                   0
# 016                                                  0
# ...                                                ...
# zin                                                  0
# zinbpimb                                             0
# zone                                                 0
# zones                                                0
# zulkifleeabbas                                       0
#
# title           bank negara ensures sufficient ringgit liquidity in onshore market  \
# 003                                                             0
# 006                                                             0
# 0088                                                            0
# 01                                                              0
# 016                                                             0
# ...                                                           ...
# zin                                                             0
# zinbpimb                                                        0
# zone                                                            0
# zones                                                           0
# zulkifleeabbas                                                  0
#
# title           why are not all glcs roped in to contribute  \
# 003                                                       0
# 006                                                       0
# 0088                                                      0
# 01                                                        0
# 016                                                       0
# ...                                                     ...
# zin                                                       0
# zinbpimb                                                  0
# zone                                                      0
# zones                                                     0
# zulkifleeabbas                                            0
#
# title           moratorium is automatic says bank negara  \
# 003                                                    0
# 006                                                    0
# 0088                                                   0
# 01                                                     0
# 016                                                    0
# ...                                                  ...
# zin                                                    0
# zinbpimb                                               0
# zone                                                   0
# zones                                                  0
# zulkifleeabbas                                         0
#
# title           bank negara no need to apply interest will be accrued  ...  \
# 003                                                             0      ...
# 006                                                             0      ...
# 0088                                                            0      ...
# 01                                                              0      ...
# 016                                                             0      ...
# ...                                                           ...      ...
# zin                                                             0      ...
# zinbpimb                                                        0      ...
# zone                                                            0      ...
# zones                                                           0      ...
# zulkifleeabbas                                                  0      ...
#
# title           greater efforts needed  to boost islamic financing  \
# 003                                                             0
# 006                                                             0
# 0088                                                            0
# 01                                                              0
# 016                                                             0
# ...                                                           ...
# zin                                                             0
# zinbpimb                                                        0
# zone                                                            0
# zones                                                           0
# zulkifleeabbas                                                  0
#
# title           challenges in fiscal consolidation process  \
# 003                                                      0
# 006                                                      0
# 0088                                                     0
# 01                                                       0
# 016                                                      0
# ...                                                    ...
# zin                                                      0
# zinbpimb                                                 0
# zone                                                     0
# zones                                                    0
# zulkifleeabbas                                           0
#
# title           bank industri posts record pretax profit  \
# 003                                                    0
# 006                                                    0
# 0088                                                   0
# 01                                                     0
# 016                                                    0
# ...                                                  ...
# zin                                                    0
# zinbpimb                                               0
# zone                                                   0
# zones                                                  0
# zulkifleeabbas                                         0
#
# title           public bank govt stimulus impact positive  \
# 003                                                     0
# 006                                                     0
# 0088                                                    0
# 01                                                      0
# 016                                                     0
# ...                                                   ...
# zin                                                     0
# zinbpimb                                                0
# zone                                                    0
# zones                                                   0
# zulkifleeabbas                                          0
#
# title           new 3phase 5year plan to transform bsn  \
# 003                                                  0
# 006                                                  0
# 0088                                                 0
# 01                                                   0
# 016                                                  0
# ...                                                ...
# zin                                                  0
# zinbpimb                                             0
# zone                                                 0
# zones                                                0
# zulkifleeabbas                                       0
#
# title           government unveils economic stimulus package  \
# 003                                                        0
# 006                                                        0
# 0088                                                       0
# 01                                                         0
# 016                                                        0
# ...                                                      ...
# zin                                                        0
# zinbpimb                                                   0
# zone                                                       0
# zones                                                      0
# zulkifleeabbas                                             0
#
# title           benchmark ops fmm tells banks  \
# 003                                         0
# 006                                         0
# 0088                                        0
# 01                                          0
# 016                                         0
# ...                                       ...
# zin                                         0
# zinbpimb                                    0
# zone                                        0
# zones                                       0
# zulkifleeabbas                              0
#
# title           bank negara sets up sme special unit  new measures proactive  \
# 003                                                0                       0
# 006                                                0                       0
# 0088                                               0                       0
# 01                                                 0                       0
# 016                                                0                       0
# ...                                              ...                     ...
# zin                                                0                       0
# zinbpimb                                           0                       0
# zone                                               0                       0
# zones                                              0                       0
# zulkifleeabbas                                     0                       0
#
# title           19 fsmp suggestions implemented by last month
# 003                                                         0
# 006                                                         0
# 0088                                                        0
# 01                                                          0
# 016                                                         0
# ...                                                       ...
# zin                                                         0
# zinbpimb                                                    0
# zone                                                        0
# zones                                                       0
# zulkifleeabbas                                              0
#
# [9545 rows x 171 columns]

# %%
# Find the top 30 words in each news
top_dict = {}
for c in data.columns:
    top = data[c].sort_values(ascending=False).head(30)
    top_dict[c]= list(zip(top.index, top.values))

top_dict
# Out:
# {'dfis should be assessed beyond financial performance': [('dfis', 10),
#   ('said', 6),
#   ('role', 6),
#   ('terms', 5),
#   ('performance', 5),
#   ('new', 4),
#   ('support', 4),
#   ('mandate', 3),
#   ('anuar', 3),
#   ('economy', 3),
#   ('areas', 3),
#   ('malaysia', 3),
#   ('dfi', 3),
#   ('banks', 3),
#   ('bank', 3),
#   ('financial', 3),
#   ('government', 3),
#   ('noted', 2),
#   ('set', 2),
#   ('growth', 2),
#   ('khairil', 2),
#   ('crisis', 2),
#   ('sme', 2),
#   ('mandated', 2),
#   ('smes', 2),
#   ('development', 2),
#   ('deliverables', 2),
#   ('different', 2),
#   ('play', 2),
#   ('looking', 2)],
#  'bank pembangunan 2019 pretax profit jumps declares rm152m dividend': [('financial',
#    4),
#   ('bank', 4),
#   ('banks', 4),
#   ('pembangunan', 3),
#   ('share', 2),
#   ('income', 2),
#   ('plan', 2),
#   ('dividend', 2),
#   ('net', 2),
#   ('total', 2),
#   ('said', 2),
#   ('higher', 2),
#   ('performance', 2),
#   ('institutions', 1),
#   ('notes', 1),
#   ('fy19', 1),
#   ('allowance', 1),
#   ('lumpur', 1),
#   ('lowest', 1),
#   ('lower', 1),
#   ('reduced', 1),
#   ('rm380mil', 1),
#   ('executing', 1),
#   ('gains', 1),
#   ('notably', 1),
#   ('redeemable', 1),
#   ('fy2019', 1),
#   ('remains', 1),
#   ('rm25bil', 1),
#   ('special', 1)],
#  'as lockdowns ease a bronx nail salon plans a careful reopening': [('caraballo',
#    7),
#   ('nail', 6),
#   ('salon', 5),
#   ('ppp', 4),
#   ('new', 4),
#   ('billion', 4),
#   ('said', 3),
#   ('help', 3),
#   ('businesses', 3),
#   ('ago', 3),
#   ('half', 3),
#   ('york', 3),
#   ('loans', 3),
#   ('clients', 3),
#   ('month', 3),
#   ('rent', 3),
#   ('small', 2),
#   ('estimates', 2),
#   ('know', 2),
#   ('business', 2),
#   ('funds', 2),
#   ('usual', 2),
#   ('nearly', 2),
#   ('applied', 2),
#   ('years', 2),
#   ('customers', 2),
#   ('government', 2),
#   ('technicians', 2),
#   ('cleaning', 2),
#   ('minority', 2)],
#  'us fed says working to broaden access to ppp facility beyond banks': [('banks',
#    3),
#   ('program', 3),
#   ('institutions', 3),
#   ('small', 2),
#   ('loans', 2),
#   ('business', 2),
#   ('financial', 2),
#   ('fed', 2),
#   ('paycheck', 1),
#   ('washington', 1),
#   ('announce', 1),
#   ('including', 1),
#   ('allows', 1),
#   ('thursday', 1),
#   ('borrow', 1),
#   ('rules', 1),
#   ('shortly', 1),
#   ('ppp', 1),
#   ('broader', 1),
#   ('deposittaking', 1),
#   ('federal', 1),
#   ('use', 1),
#   ('array', 1),
#   ('reserve', 1),
#   ('lending', 1),
#   ('administrations', 1),
#   ('said', 1),
#   ('currently', 1),
#   ('expand', 1),
#   ('new', 1)],
#  'bank negara to ensure sufficient ringgit liquidity': [('financial', 11),
#   ('liquidity', 10),
#   ('market', 10),
#   ('bank', 9),
#   ('said', 8),
#   ('fiscal', 6),
#   ('markets', 6),
#   ('negara', 5),
#   ('dollar', 5),
#   ('central', 4),
#   ('committee', 4),
#   ('onshore', 4),
#   ('economic', 4),
#   ('global', 4),
#   ('repo', 4),
#   ('commitment', 3),
#   ('continue', 3),
#   ('activities', 3),
#   ('sufficient', 3),
#   ('acknowledged', 3),
#   ('participants', 3),
#   ('including', 2),
#   ('discussed', 2),
#   ('agreements', 2),
#   ('increase', 2),
#   ('ensure', 2),
#   ('preemptively', 2),
#   ('government', 2),
#   ('ringgit', 2),
#   ('recent', 2)],
#  'providing sme support in times of need': [('financing', 13),
#   ('smes', 10),
#   ('cgc', 7),
#   ('facility', 4),
#   ('sme', 4),
#   ('pfis', 3),
#   ('guarantee', 3),
#   ('moratorium', 3),
#   ('apply', 3),
#   ('imsme', 3),
#   ('financial', 3),
#   ('visit', 3),
#   ('srf', 3),
#   ('bnm', 3),
#   ('contact', 3),
#   ('bizmulai', 2),
#   ('existing', 2),
#   ('imsmecommy', 2),
#   ('bizwanitai', 2),
#   ('annum', 2),
#   ('years', 2),
#   ('institutions', 2),
#   ('economic', 2),
#   ('customers', 2),
#   ('business', 2),
#   ('sixmonth', 2),
#   ('supporting', 2),
#   ('schemes', 2),
#   ('ongoing', 2),
#   ('banks', 2)],
#  'bank negara ensures sufficient ringgit liquidity in onshore market': [('financial',
#    11),
#   ('market', 10),
#   ('liquidity', 10),
#   ('said', 9),
#   ('bank', 8),
#   ('markets', 6),
#   ('fiscal', 6),
#   ('dollar', 5),
#   ('repo', 4),
#   ('central', 4),
#   ('negara', 4),
#   ('committee', 4),
#   ('onshore', 4),
#   ('global', 4),
#   ('economic', 4),
#   ('sufficient', 3),
#   ('activities', 3),
#   ('participants', 3),
#   ('commitment', 3),
#   ('continue', 3),
#   ('acknowledged', 3),
#   ('including', 2),
#   ('stimulus', 2),
#   ('ensure', 2),
#   ('banks', 2),
#   ('agreements', 2),
#   ('preemptively', 2),
#   ('funding', 2),
#   ('discussed', 2),
#   ('conditions', 2)],
#  'why are not all glcs roped in to contribute': [('government', 21),
#   ('minister', 11),
#   ('bank', 10),
#   ('package', 9),
#   ('stimulus', 9),
#   ('crisis', 8),
#   ('ecosystem', 8),
#   ('prime', 8),
#   ('glcs', 7),
#   ('economy', 6),
#   ('people', 5),
#   ('funds', 5),
#   ('nexus', 5),
#   ('need', 5),
#   ('muhyiddin', 5),
#   ('power', 4),
#   ('powerful', 4),
#   ('institutions', 4),
#   ('help', 4),
#   ('firms', 3),
#   ('political', 3),
#   ('sme', 3),
#   ('major', 3),
#   ('perikatan', 3),
#   ('offer', 3),
#   ('support', 3),
#   ('mara', 3),
#   ('epf', 3),
#   ('politicalbusiness', 3),
#   ('nasional', 3)],
#  'moratorium is automatic says bank negara': [('deferment', 38),
#   ('loanfinancing', 29),
#   ('repayment', 21),
#   ('package', 18),
#   ('credit', 17),
#   ('banks', 16),
#   ('period', 15),
#   ('borrowerscustomers', 14),
#   ('bank', 12),
#   ('loansfinancing', 12),
#   ('card', 11),
#   ('deferred', 10),
#   ('continue', 10),
#   ('outstanding', 10),
#   ('repayments', 10),
#   ('meet', 9),
#   ('qualify', 9),
#   ('institutions', 9),
#   ('monthly', 8),
#   ('term', 8),
#   ('yes', 7),
#   ('financial', 7),
#   ('months', 7),
#   ('financing', 7),
#   ('loans', 6),
#   ('loan', 6),
#   ('need', 6),
#   ('criteria', 6),
#   ('april', 5),
#   ('automatically', 5)],
#  'bank negara no need to apply interest will be accrued': [('deferment', 35),
#   ('loanfinancing', 29),
#   ('repayment', 20),
#   ('credit', 17),
#   ('borrowerscustomers', 14),
#   ('period', 14),
#   ('banks', 12),
#   ('loansfinancing', 11),
#   ('bank', 11),
#   ('deferred', 10),
#   ('institutions', 10),
#   ('outstanding', 10),
#   ('card', 10),
#   ('continue', 10),
#   ('package', 10),
#   ('repayments', 10),
#   ('qualify', 9),
#   ('meet', 9),
#   ('monthly', 8),
#   ('term', 8),
#   ('financial', 8),
#   ('financing', 7),
#   ('months', 7),
#   ('loan', 6),
#   ('criteria', 6),
#   ('need', 6),
#   ('individuals', 5),
#   ('accrue', 5),
#   ('wish', 5),
#   ('april', 5)],
#  'bank negara releases faq': [('services', 24),
#   ('period', 19),
#   ('providers', 12),
#   ('financial', 12),
#   ('mco', 12),
#   ('bank', 11),
#   ('essential', 9),
#   ('service', 8),
#   ('branches', 8),
#   ('containment', 8),
#   ('insurance', 7),
#   ('work', 7),
#   ('need', 6),
#   ('epayment', 6),
#   ('open', 6),
#   ('banks', 6),
#   ('banking', 6),
#   ('operating', 6),
#   ('atms', 6),
#   ('online', 5),
#   ('check', 5),
#   ('cash', 5),
#   ('terminals', 5),
#   ('access', 5),
#   ('money', 5),
#   ('counter', 5),
#   ('refer', 5),
#   ('remittance', 4),
#   ('operations', 4),
#   ('yes', 4)],
#  'essential financial services remain accessible': [('services', 9),
#   ('financial', 6),
#   ('ensure', 6),
#   ('providers', 6),
#   ('bank', 6),
#   ('public', 6),
#   ('money', 6),
#   ('said', 5),
#   ('service', 4),
#   ('period', 4),
#   ('negara', 4),
#   ('banking', 3),
#   ('remittance', 3),
#   ('open', 3),
#   ('containment', 3),
#   ('continue', 3),
#   ('members', 3),
#   ('remain', 3),
#   ('central', 2),
#   ('advised', 2),
#   ('uninterrupted', 2),
#   ('refer', 2),
#   ('branches', 2),
#   ('essential', 2),
#   ('customers', 2),
#   ('institutions', 2),
#   ('insurance', 2),
#   ('online', 2),
#   ('operators', 2),
#   ('end', 2)],
#  'reaching out to the smes': [('bank', 21),
#   ('financing', 14),
#   ('rakyat', 8),
#   ('cooperatives', 8),
#   ('malaysia', 7),
#   ('rosman', 7),
#   ('bhd', 6),
#   ('smes', 5),
#   ('personal', 5),
#   ('banks', 5),
#   ('development', 4),
#   ('banking', 4),
#   ('said', 3),
#   ('cooperative', 3),
#   ('dfis', 3),
#   ('grow', 3),
#   ('portfolio', 3),
#   ('small', 3),
#   ('looking', 2),
#   ('account', 2),
#   ('2018', 2),
#   ('financial', 2),
#   ('sme', 2),
#   ('plan', 2),
#   ('medium', 2),
#   ('home', 2),
#   ('sector', 2),
#   ('coming', 2),
#   ('government', 2),
#   ('islamic', 2)],
#  'pressure mounts on government as economic worries intensify': [('growth',
#    16),
#   ('fiscal', 14),
#   ('economy', 13),
#   ('stimulus', 12),
#   ('economic', 10),
#   ('package', 10),
#   ('bank', 9),
#   ('governments', 9),
#   ('deficit', 8),
#   ('quarter', 8),
#   ('2020', 8),
#   ('4q19', 8),
#   ('investment', 7),
#   ('government', 7),
#   ('says', 6),
#   ('expects', 6),
#   ('private', 5),
#   ('rate', 5),
#   ('rating', 4),
#   ('domestic', 4),
#   ('outbreak', 4),
#   ('commodity', 4),
#   ('3q19', 4),
#   ('market', 4),
#   ('yoy', 4),
#   ('economist', 4),
#   ('1q20', 4),
#   ('continue', 4),
#   ('supply', 4),
#   ('manokaran', 4)],
#  'dfi merger talks begin': [('bank', 15),
#   ('dfis', 13),
#   ('financing', 11),
#   ('merger', 11),
#   ('sme', 10),
#   ('bpmb', 9),
#   ('development', 7),
#   ('bhd', 6),
#   ('malaysia', 5),
#   ('institutions', 5),
#   ('economy', 4),
#   ('year', 4),
#   ('committee', 4),
#   ('said', 4),
#   ('danajamin', 4),
#   ('provide', 4),
#   ('ministry', 4),
#   ('business', 4),
#   ('businesses', 4),
#   ('expected', 3),
#   ('needs', 3),
#   ('analyst', 3),
#   ('financial', 3),
#   ('banking', 3),
#   ('mandates', 3),
#   ('phase', 3),
#   ('restructuring', 3),
#   ('new', 3),
#   ('added', 3),
#   ('proposal', 3)],
#  'bank pembangunan danajamin receive bnm approval for merger talks': [('bank',
#    7),
#   ('merger', 6),
#   ('bpmb', 5),
#   ('danajamin', 4),
#   ('bhd', 4),
#   ('malaysia', 3),
#   ('development', 3),
#   ('said', 2),
#   ('committee', 2),
#   ('governments', 2),
#   ('negara', 2),
#   ('expected', 2),
#   ('phase', 2),
#   ('steering', 2),
#   ('working', 1),
#   ('comittee', 1),
#   ('achieve', 1),
#   ('commence', 1),
#   ('needs', 1),
#   ('bpmbphase', 1),
#   ('greater', 1),
#   ('support', 1),
#   ('budget', 1),
#   ('negotiations', 1),
#   ('corp', 1),
#   ('various', 1),
#   ('comprising', 1),
#   ('entitythere', 1),
#   ('given', 1),
#   ('green', 1)],
#  'bank rakyat 9m pbtz up 4 to rm129b': [('financing', 6),
#   ('bank', 5),
#   ('said', 4),
#   ('groups', 4),
#   ('islamic', 3),
#   ('profit', 3),
#   ('group', 3),
#   ('profits', 3),
#   ('rakyat', 3),
#   ('cir', 2),
#   ('performance', 2),
#   ('rate', 2),
#   ('higher', 2),
#   ('noripah', 2),
#   ('activities', 2),
#   ('largest', 2),
#   ('asset', 2),
#   ('cost', 2),
#   ('pbtz', 2),
#   ('encouraging', 2),
#   ('sustainable', 2),
#   ('institution', 2),
#   ('development', 2),
#   ('contributed', 2),
#   ('treasury', 2),
#   ('banking', 2),
#   ('nations', 1),
#   ('affected', 1),
#   ('20', 1),
#   ('friday', 1)],
#  'budget 2020 – a visionary change towards spv2030': [('budget', 10),
#   ('year', 8),
#   ('2020', 7),
#   ('tax', 6),
#   ('likely', 6),
#   ('minister', 5),
#   ('proposals', 5),
#   ('expected', 5),
#   ('property', 4),
#   ('growth', 4),
#   ('investments', 4),
#   ('cost', 4),
#   ('new', 4),
#   ('given', 4),
#   ('base', 3),
#   ('khazanah', 3),
#   ('income', 3),
#   ('reduction', 3),
#   ('investment', 3),
#   ('high', 3),
#   ('governments', 3),
#   ('sector', 3),
#   ('market', 3),
#   ('surprise', 3),
#   ('time', 3),
#   ('toll', 3),
#   ('far', 3),
#   ('economic', 3),
#   ('solar', 3),
#   ('spur', 3)],
#  'plan to merge 4 dfis can improve efficiencies': [('bank', 12),
#   ('dfis', 10),
#   ('institutions', 6),
#   ('development', 4),
#   ('pembangunan', 4),
#   ('mandates', 3),
#   ('bhd', 3),
#   ('merger', 3),
#   ('proposal', 3),
#   ('year', 3),
#   ('malaysia', 3),
#   ('said', 3),
#   ('new', 3),
#   ('financial', 3),
#   ('performance', 3),
#   ('entity', 2),
#   ('operations', 2),
#   ('financing', 2),
#   ('sme', 2),
#   ('develop', 2),
#   ('finance', 2),
#   ('needs', 2),
#   ('focus', 2),
#   ('turn', 2),
#   ('strengthen', 2),
#   ('synergies', 2),
#   ('indicators', 2),
#   ('economy', 2),
#   ('negara', 2),
#   ('greater', 2)],
#  'industry players and ceos give their views': [('digital', 14),
#   ('scheme', 14),
#   ('governments', 11),
#   ('government', 11),
#   ('growth', 11),
#   ('smes', 11),
#   ('budget', 10),
#   ('economy', 9),
#   ('financing', 8),
#   ('group', 7),
#   ('support', 7),
#   ('2020', 7),
#   ('year', 7),
#   ('bhd', 6),
#   ('measures', 6),
#   ('ltat', 6),
#   ('tax', 6),
#   ('boost', 5),
#   ('incentives', 5),
#   ('economic', 5),
#   ('datuk', 5),
#   ('ceo', 5),
#   ('welcome', 5),
#   ('technology', 5),
#   ('adoption', 5),
#   ('help', 5),
#   ('investment', 4),
#   ('increase', 4),
#   ('housing', 4),
#   ('development', 4)],
#  'full text of budget 2020 speech': [('government', 85),
#   ('million', 80),
#   ('malaysia', 37),
#   ('digital', 34),
#   ('year', 31),
#   ('2020', 30),
#   ('billion', 30),
#   ('years', 28),
#   ('new', 27),
#   ('tax', 25),
#   ('development', 23),
#   ('2019', 21),
#   ('economic', 21),
#   ('allocate', 21),
#   ('second', 20),
#   ('growth', 20),
#   ('companies', 19),
#   ('sri', 18),
#   ('income', 18),
#   ('malaysian', 18),
#   ('malaysians', 16),
#   ('speaker', 16),
#   ('fund', 16),
#   ('sir', 15),
#   ('support', 15),
#   ('provide', 15),
#   ('tan', 15),
#   ('smes', 15),
#   ('given', 15),
#   ('economy', 15)],
#  'budget 2020 four dfis to merge into one entity': [('bank', 6),
#   ('bhd', 3),
#   ('malaysia', 3),
#   ('development', 3),
#   ('dfis', 2),
#   ('financial', 1),
#   ('strengthen', 1),
#   ('entity', 1),
#   ('exportimport', 1),
#   ('finance', 1),
#   ('lumpur', 1),
#   ('sme', 1),
#   ('institutions', 1),
#   ('pembangunan', 1),
#   ('exim', 1),
#   ('restructuring', 1),
#   ('enterprise', 1),
#   ('negara', 1),
#   ('kuala', 1),
#   ('small', 1),
#   ('danajamin', 1),
#   ('nasional', 1),
#   ('single', 1),
#   ('plan', 1),
#   ('berhad', 1),
#   ('proposed', 1),
#   ('twostage', 1),
#   ('medium', 1),
#   ('ecosystem', 1),
#   ('merge', 1)],
#  'insightful workshop for entrepreneurs': [('smes', 11),
#   ('business', 10),
#   ('says', 8),
#   ('bhd', 7),
#   ('star', 5),
#   ('resources', 5),
#   ('trade', 5),
#   ('lim', 5),
#   ('soba', 5),
#   ('relevant', 4),
#   ('ecosystem', 4),
#   ('agencies', 4),
#   ('products', 4),
#   ('market', 4),
#   ('eye', 4),
#   ('malaysia', 4),
#   ('growth', 4),
#   ('development', 4),
#   ('officer', 4),
#   ('chief', 4),
#   ('sdn', 4),
#   ('group', 4),
#   ('customers', 3),
#   ('senhengs', 3),
#   ('teh', 3),
#   ('learning', 3),
#   ('key', 3),
#   ('years', 3),
#   ('addaem', 3),
#   ('2019', 3)],
#  'sme bank targets higher financing': [('bank', 16),
#   ('sme', 15),
#   ('smes', 10),
#   ('financing', 9),
#   ('programme', 7),
#   ('said', 7),
#   ('business', 6),
#   ('digital', 6),
#   ('transformation', 6),
#   ('total', 5),
#   ('aria', 5),
#   ('role', 5),
#   ('putera', 5),
#   ('competition', 5),
#   ('assist', 4),
#   ('entrepreneurs', 4),
#   ('targeted', 4),
#   ('various', 4),
#   ('year', 4),
#   ('malaysia', 3),
#   ('higher', 3),
#   ('development', 3),
#   ('2018', 3),
#   ('banks', 3),
#   ('sales', 3),
#   ('conducted', 3),
#   ('financial', 3),
#   ('export', 3),
#   ('participants', 3),
#   ('cedar', 3)],
#  'increase in financing for cooperatives depends on bank rakyats capability': [('bank',
#    7),
#   ('financing', 7),
#   ('banks', 5),
#   ('financial', 4),
#   ('said', 4),
#   ('rakyat', 4),
#   ('grew', 3),
#   ('previously', 3),
#   ('plan', 2),
#   ('national', 2),
#   ('dividend', 2),
#   ('based', 2),
#   ('cooperatives', 2),
#   ('compared', 2),
#   ('development', 2),
#   ('datuk', 2),
#   ('report', 2),
#   ('board', 2),
#   ('fy18', 2),
#   ('directors', 2),
#   ('13', 2),
#   ('noripah', 2),
#   ('efforts', 2),
#   ('business', 2),
#   ('increase', 2),
#   ('especially', 2),
#   ('home', 2),
#   ('rakyats', 2),
#   ('amounting', 1),
#   ('balance', 1)],
#  'ambank bags a double at cgc sme awards': [('award', 4),
#   ('fi', 4),
#   ('financial', 4),
#   ('bumiputera', 3),
#   ('category', 3),
#   ('awards', 3),
#   ('commitment', 2),
#   ('cgc', 2),
#   ('recognises', 2),
#   ('providing', 2),
#   ('fis', 2),
#   ('credit', 2),
#   ('partner', 2),
#   ('bhd', 2),
#   ('guarantee', 2),
#   ('financing', 2),
#   ('smes', 2),
#   ('appreciation', 1),
#   ('recent', 1),
#   ('receive', 1),
#   ('support', 1),
#   ('lumpur', 1),
#   ('relevant', 1),
#   ('ambank', 1),
#   ('needs', 1),
#   ('corporation', 1),
#   ('datuk', 1),
#   ('institution', 1),
#   ('executive', 1),
#   ('testament', 1)],
#  'time to boost islamic deposits': [('islamic', 28),
#   ('banking', 15),
#   ('said', 9),
#   ('growth', 7),
#   ('badlisyah', 7),
#   ('industry', 7),
#   ('banks', 6),
#   ('deposits', 6),
#   ('finance', 5),
#   ('funds', 5),
#   ('asset', 5),
#   ('growing', 4),
#   ('noted', 4),
#   ('institutional', 3),
#   ('financing', 3),
#   ('conventional', 3),
#   ('attract', 3),
#   ('needs', 3),
#   ('term', 3),
#   ('vbi', 3),
#   ('ciif', 3),
#   ('size', 3),
#   ('professionals', 2),
#   ('long', 2),
#   ('intermediation', 2),
#   ('professional', 2),
#   ('11', 2),
#   ('expected', 2),
#   ('body', 2),
#   ('total', 2)],
#  'understanding sme financing in malaysia': [('financing', 25),
#   ('smes', 14),
#   ('bank', 12),
#   ('business', 12),
#   ('respondents', 11),
#   ('financial', 10),
#   ('firms', 10),
#   ('says', 10),
#   ('survey', 10),
#   ('institutions', 8),
#   ('insufficient', 6),
#   ('applications', 6),
#   ('higher', 6),
#   ('sources', 5),
#   ('mainly', 5),
#   ('22', 5),
#   ('cash', 5),
#   ('applied', 5),
#   ('costs', 5),
#   ('central', 5),
#   ('negara', 5),
#   ('documentation', 5),
#   ('services', 4),
#   ('rejection', 4),
#   ('2018', 4),
#   ('products', 4),
#   ('main', 4),
#   ('reported', 4),
#   ('average', 3),
#   ('funds', 3)],
#  'enhancing the role of development financial institutions': [('dfis', 13),
#   ('development', 6),
#   ('framework', 6),
#   ('performance', 6),
#   ('bank', 6),
#   ('focus', 3),
#   ('mandates', 3),
#   ('impact', 3),
#   ('measurement', 3),
#   ('finance', 2),
#   ('necessary', 2),
#   ('aims', 2),
#   ('continue', 2),
#   ('2018', 2),
#   ('world', 2),
#   ('institutions', 2),
#   ('effectively', 2),
#   ('key', 2),
#   ('growth', 2),
#   ('financing', 2),
#   ('enhanced', 2),
#   ('central', 2),
#   ('financial', 2),
#   ('new', 2),
#   ('indicators', 2),
#   ('petaling', 1),
#   ('measure', 1),
#   ('optimising', 1),
#   ('malaysia', 1),
#   ('supervisory', 1)],
#  'tailormade for women': [('smes', 11),
#   ('women', 11),
#   ('cgc', 10),
#   ('said', 9),
#   ('mohd', 8),
#   ('financing', 8),
#   ('malaysia', 7),
#   ('scheme', 7),
#   ('chartered', 6),
#   ('entrepreneurs', 6),
#   ('standard', 6),
#   ('financial', 6),
#   ('tranches', 5),
#   ('institutions', 5),
#   ('pg', 5),
#   ('guarantee', 5),
#   ('chief', 5),
#   ('officer', 5),
#   ('scm', 5),
#   ('zamree', 5),
#   ('abrar', 4),
#   ('collaboration', 4),
#   ('amiruddin', 4),
#   ('saadiq', 4),
#   ('anniversary', 3),
#   ('finance', 3),
#   ('development', 3),
#   ('economy', 3),
#   ('need', 3),
#   ('inclusion', 3)],
#  'bank negara issues policy paper on outsourcing': [('outsourcing', 9),
#   ('management', 7),
#   ('policy', 5),
#   ('senior', 4),
#   ('financial', 4),
#   ('board', 4),
#   ('banks', 4),
#   ('document', 4),
#   ('plan', 3),
#   ('risk', 3),
#   ('requirements', 3),
#   ('arrangements', 3),
#   ('institutions', 3),
#   ('ability', 2),
#   ('bank', 2),
#   ('service', 2),
#   ('obtain', 2),
#   ('statement', 2),
#   ('governance', 2),
#   ('customers', 2),
#   ('oversight', 2),
#   ('feedback', 2),
#   ('ensure', 2),
#   ('issued', 2),
#   ('negara', 2),
#   ('planning', 2),
#   ('effective', 2),
#   ('concurrently', 1),
#   ('strong', 1),
#   ('year', 1)],
#  'rhb bank bsn bank of china offer lowest lending rates': [('bank', 12),
#   ('base', 11),
#   ('rate', 8),
#   ('rhb', 6),
#   ('bhd', 6),
#   ('rates', 6),
#   ('blr', 6),
#   ('islamic', 5),
#   ('bhds', 4),
#   ('bfr', 3),
#   ('financing', 2),
#   ('bsn', 2),
#   ('685', 2),
#   ('lending', 2),
#   ('highest', 2),
#   ('banks', 2),
#   ('financial', 2),
#   ('institutions', 2),
#   ('malaysia', 2),
#   ('lendingfinancing', 1),
#   ('end', 1),
#   ('410', 1),
#   ('malayan', 1),
#   ('house', 1),
#   ('webiste', 1),
#   ('407', 1),
#   ('bangkok', 1),
#   ('405', 1),
#   ('365', 1),
#   ('737', 1)],
#  'standing tall together': [('bhd', 17),
#   ('chinese', 16),
#   ('malays', 15),
#   ('malaysia', 14),
#   ('population', 6),
#   ('indians', 6),
#   ('politicians', 6),
#   ('police', 6),
#   ('million', 6),
#   ('companies', 5),
#   ('nonmalays', 5),
#   ('race', 5),
#   ('government', 5),
#   ('malaysian', 5),
#   ('malay', 5),
#   ('country', 5),
#   ('service', 4),
#   ('report', 4),
#   ('bumiputra', 4),
#   ('civil', 4),
#   ('new', 4),
#   ('ethnic', 4),
#   ('force', 4),
#   ('percentage', 4),
#   ('group', 4),
#   ('army', 4),
#   ('according', 4),
#   ('2015', 4),
#   ('glcs', 3),
#   ('bumiputera', 3)],
#  'strong growth in car loan applications approvals during tax holiday': [('cent',
#    14),
#   ('said', 6),
#   ('growth', 6),
#   ('outstanding', 5),
#   ('july', 5),
#   ('bnm', 4),
#   ('month', 4),
#   ('august', 4),
#   ('loan', 3),
#   ('central', 3),
#   ('capital', 3),
#   ('respectively', 3),
#   ('financial', 3),
#   ('increased', 3),
#   ('banking', 3),
#   ('bank', 3),
#   ('corporate', 2),
#   ('financing', 2),
#   ('support', 2),
#   ('applications', 2),
#   ('rising', 2),
#   ('threemonth', 2),
#   ('2018', 2),
#   ('net', 2),
#   ('monthly', 2),
#   ('ringgits', 2),
#   ('basel', 2),
#   ('approvals', 2),
#   ('institutions', 2),
#   ('outflows', 2)],
#  'bank negara dfis need to diversify sources of funding': [('dfis', 10),
#   ('development', 6),
#   ('financial', 6),
#   ('shamsiah', 5),
#   ('said', 5),
#   ('bank', 4),
#   ('negara', 4),
#   ('landscape', 3),
#   ('added', 3),
#   ('sustainable', 3),
#   ('support', 3),
#   ('institutions', 3),
#   ('mandates', 3),
#   ('success', 3),
#   ('deliver', 3),
#   ('positive', 3),
#   ('maturity', 2),
#   ('proportionality', 2),
#   ('greater', 2),
#   ('zero', 2),
#   ('diversify', 2),
#   ('application', 2),
#   ('institution', 2),
#   ('society', 2),
#   ('remain', 2),
#   ('long', 2),
#   ('important', 2),
#   ('ensure', 2),
#   ('funding', 2),
#   ('business', 2)],
#  'dfis need to ensure long term financial sustainability': [('dfis', 9),
#   ('said', 6),
#   ('development', 4),
#   ('financial', 4),
#   ('support', 3),
#   ('sustainable', 3),
#   ('shamsiah', 3),
#   ('bnm', 3),
#   ('contribute', 2),
#   ('business', 2),
#   ('application', 2),
#   ('proportionality', 2),
#   ('good', 2),
#   ('health', 2),
#   ('greater', 2),
#   ('zero', 2),
#   ('added', 2),
#   ('foundation', 2),
#   ('building', 2),
#   ('mandates', 2),
#   ('consumption', 1),
#   ('datuk', 1),
#   ('grounded', 1),
#   ('longterm', 1),
#   ('dfi', 1),
#   ('executing', 1),
#   ('dependent', 1),
#   ('externalities', 1),
#   ('long', 1),
#   ('level', 1)],
#  'cgc awards financial institutions and customers for participating in schemes': [('cgc',
#    10),
#   ('bhd', 6),
#   ('financial', 5),
#   ('smes', 5),
#   ('awards', 4),
#   ('guarantee', 4),
#   ('sme', 4),
#   ('bank', 4),
#   ('said', 4),
#   ('partner', 4),
#   ('fi', 3),
#   ('award', 3),
#   ('maybank', 3),
#   ('banking', 3),
#   ('financing', 3),
#   ('customers', 3),
#   ('institutions', 3),
#   ('record', 3),
#   ('datuk', 2),
#   ('demonstrated', 2),
#   ('products', 2),
#   ('customer', 2),
#   ('hassan', 2),
#   ('exemplary', 2),
#   ('new', 2),
#   ('category', 2),
#   ('fis', 2),
#   ('track', 2),
#   ('islamic', 2),
#   ('presented', 2)],
#  'its time to tame the glc monster': [('glcs', 33),
#   ('government', 16),
#   ('companies', 13),
#   ('private', 7),
#   ('firms', 7),
#   ('economy', 7),
#   ('ownership', 6),
#   ('institutions', 6),
#   ('reforms', 6),
#   ('politicians', 5),
#   ('economic', 5),
#   ('minister', 5),
#   ('business', 5),
#   ('listed', 5),
#   ('enterprises', 5),
#   ('finance', 4),
#   ('role', 4),
#   ('equity', 4),
#   ('structure', 4),
#   ('new', 4),
#   ('sector', 4),
#   ('sectors', 4),
#   ('professionals', 4),
#   ('serve', 3),
#   ('reform', 3),
#   ('play', 3),
#   ('dr', 3),
#   ('number', 3),
#   ('public', 3),
#   ('complex', 3)],
#  'bank negara says rm33b funds still available for smes': [('smes', 14),
#   ('said', 9),
#   ('cent', 8),
#   ('fund', 5),
#   ('institutions', 5),
#   ('financial', 5),
#   ('financing', 5),
#   ('bank', 4),
#   ('total', 3),
#   ('marina', 3),
#   ('funding', 3),
#   ('funds', 3),
#   ('provided', 3),
#   ('billion', 3),
#   ('bnm', 3),
#   ('97', 2),
#   ('programme', 2),
#   ('assisted', 2),
#   ('million', 2),
#   ('available', 2),
#   ('business', 2),
#   ('ensure', 2),
#   ('awareness', 2),
#   ('matters', 2),
#   ('small', 2),
#   ('sme', 2),
#   ('officers', 2),
#   ('finance', 2),
#   ('negara', 2),
#   ('ttt', 2)],
#  'mohd zamree wins 2018 outstanding ceo award': [('cgc', 6),
#   ('development', 5),
#   ('financing', 4),
#   ('ceo', 3),
#   ('award', 3),
#   ('mohd', 3),
#   ('institutions', 3),
#   ('financial', 3),
#   ('2018', 2),
#   ('outstanding', 2),
#   ('sme', 2),
#   ('smes', 2),
#   ('respective', 2),
#   ('credit', 2),
#   ('medium', 1),
#   ('organisations', 1),
#   ('improve', 1),
#   ('organisation', 1),
#   ('imsmezamree', 1),
#   ('domestic', 1),
#   ('1976', 1),
#   ('selected', 1),
#   ('ishak', 1),
#   ('like', 1),
#   ('recognition', 1),
#   ('petaling', 1),
#   ('line', 1),
#   ('express', 1),
#   ('founded', 1),
#   ('adfiap', 1)],
#  'bank negaras rm500m disaster relief fund for floodhit smes': [('bank', 8),
#   ('financing', 7),
#   ('financial', 5),
#   ('said', 5),
#   ('affected', 5),
#   ('bnm', 5),
#   ('facility', 5),
#   ('bhd', 4),
#   ('smes', 4),
#   ('institutions', 4),
#   ('public', 3),
#   ('malaysia', 3),
#   ('flood', 3),
#   ('available', 3),
#   ('assistance', 3),
#   ('contact', 2),
#   ('disaster', 2),
#   ('recent', 2),
#   ('guarantee', 2),
#   ('rate', 2),
#   ('negara', 2),
#   ('floods', 2),
#   ('advised', 2),
#   ('relief', 1),
#   ('maximum', 1),
#   ('districts', 1),
#   ('medium', 1),
#   ('60', 1),
#   ('come', 1),
#   ('cimb', 1)],
#  'govt debt is moderate says finance ministry': [('debt', 5),
#   ('said', 5),
#   ('institutions', 5),
#   ('ministry', 4),
#   ('domestic', 4),
#   ('credit', 3),
#   ('government', 3),
#   ('bank', 2),
#   ('act', 2),
#   ('gdp', 2),
#   ('consumer', 2),
#   ('10', 2),
#   ('banking', 2),
#   ('sales', 2),
#   ('held', 2),
#   ('funds', 2),
#   ('foreign', 2),
#   ('companies', 2),
#   ('total', 2),
#   ('malaysia', 2),
#   ('insurance', 2),
#   ('retirement', 2),
#   ('fund', 2),
#   ('protection', 2),
#   ('businesses', 2),
#   ('cooperatives', 1),
#   ('reported', 1),
#   ('45', 1),
#   ('44the', 1),
#   ('ment', 1)],
#  'smes urged to leverage on bank negara sme fund': [('smes', 10),
#   ('fund', 9),
#   ('financing', 8),
#   ('funds', 5),
#   ('institutions', 4),
#   ('financial', 4),
#   ('sme', 3),
#   ('support', 3),
#   ('total', 3),
#   ('banks', 2),
#   ('allocation', 2),
#   ('segments', 2),
#   ('different', 2),
#   ('development', 2),
#   ('available', 2),
#   ('negara', 2),
#   ('provided', 2),
#   ('enterprises', 2),
#   ('utilised', 2),
#   ('leverage', 2),
#   ('said', 2),
#   ('bank', 2),
#   ('rates', 1),
#   ('rm302bil', 1),
#   ('islamic', 1),
#   ('sectors', 1),
#   ('continuous', 1),
#   ('purposes', 1),
#   ('capital', 1),
#   ('gross', 1)],
#  'bank negara to issue guidelines on cryptocurrencies': [('said', 16),
#   ('growth', 9),
#   ('inflation', 8),
#   ('muhammad', 7),
#   ('industry', 6),
#   ('bank', 5),
#   ('economic', 5),
#   ('financial', 5),
#   ('institutions', 5),
#   ('rate', 5),
#   ('development', 5),
#   ('korean', 5),
#   ('new', 4),
#   ('bitcoin', 4),
#   ('ringgit', 4),
#   ('exchange', 4),
#   ('cryptocurrencies', 3),
#   ('important', 3),
#   ('negara', 3),
#   ('private', 3),
#   ('economy', 3),
#   ('guidelines', 3),
#   ('investments', 3),
#   ('rely', 3),
#   ('added', 3),
#   ('sector', 3),
#   ('competitiveness', 2),
#   ('strength', 2),
#   ('investment', 2),
#   ('content', 2)],
#  'development financial institutions can be an agent of change says bnm governor': [('development',
#    12),
#   ('institutions', 7),
#   ('said', 6),
#   ('muhammad', 5),
#   ('financial', 4),
#   ('sectors', 3),
#   ('performance', 3),
#   ('private', 3),
#   ('korean', 2),
#   ('key', 2),
#   ('accountability', 2),
#   ('corporate', 2),
#   ('highlighted', 2),
#   ('increase', 2),
#   ('standards', 2),
#   ('economic', 2),
#   ('need', 2),
#   ('governance', 2),
#   ('governor', 2),
#   ('approaches', 2),
#   ('growth', 2),
#   ('frameworks', 2),
#   ('investment', 2),
#   ('provide', 2),
#   ('strengthen', 2),
#   ('contribute', 1),
#   ('societies', 1),
#   ('drive', 1),
#   ('unique', 1),
#   ('socioeconomic', 1)],
#  'bnm to issue rules on cryptocurrencies by year end': [('said', 4),
#   ('economic', 3),
#   ('guidelines', 3),
#   ('ringgit', 3),
#   ('muhammad', 3),
#   ('important', 2),
#   ('want', 2),
#   ('end', 2),
#   ('reflect', 2),
#   ('malaysia', 2),
#   ('strength', 2),
#   ('year', 2),
#   ('bnm', 2),
#   ('local', 1),
#   ('lumpur', 1),
#   ('reflective', 1),
#   ('exchange', 1),
#   ('lot', 1),
#   ('tan', 1),
#   ('looking', 1),
#   ('relating', 1),
#   ('attention', 1),
#   ('symposium', 1),
#   ('anti', 1),
#   ('global', 1),
#   ('issue', 1),
#   ('speaking', 1),
#   ('level', 1),
#   ('bank', 1),
#   ('form', 1)],
#  'net financing to private sector grew 54 in february': [('net', 7),
#   ('loans', 6),
#   ('capital', 4),
#   ('growth', 4),
#   ('banking', 4),
#   ('ratio', 4),
#   ('loan', 3),
#   ('january', 3),
#   ('pace', 3),
#   ('grew', 3),
#   ('expansion', 3),
#   ('february', 3),
#   ('54', 3),
#   ('level', 2),
#   ('annual', 2),
#   ('broad', 2),
#   ('private', 2),
#   ('continued', 2),
#   ('tier', 2),
#   ('driven', 2),
#   ('month', 2),
#   ('money', 2),
#   ('higher', 2),
#   ('sector', 2),
#   ('credit', 2),
#   ('outstanding', 2),
#   ('business', 2),
#   ('financing', 2),
#   ('extension', 1),
#   ('decline', 1)],
#  'highlights of bank negara financial stability report 2016': [('growth', 11),
#   ('financial', 11),
#   ('financing', 7),
#   ('sector', 7),
#   ('debt', 7),
#   ('islamic', 7),
#   ('banking', 7),
#   ('payment', 7),
#   ('banks', 6),
#   ('2016', 6),
#   ('motor', 6),
#   ('insurance', 6),
#   ('development', 5),
#   ('bank', 5),
#   ('market', 5),
#   ('business', 5),
#   ('takaful', 5),
#   ('total', 4),
#   ('key', 4),
#   ('2017', 4),
#   ('domestic', 4),
#   ('increased', 4),
#   ('finance', 4),
#   ('transactions', 4),
#   ('products', 4),
#   ('supported', 3),
#   ('industry', 3),
#   ('volatility', 3),
#   ('technology', 3),
#   ('businesses', 3)],
#  'malaysias economy records 45 growth in q4 of 2016': [('growth', 22),
#   ('said', 14),
#   ('2016', 13),
#   ('bnm', 9),
#   ('financial', 8),
#   ('sector', 8),
#   ('services', 7),
#   ('domestic', 7),
#   ('quarter', 6),
#   ('private', 6),
#   ('manufacturing', 6),
#   ('3q', 5),
#   ('higher', 5),
#   ('continued', 5),
#   ('continue', 5),
#   ('supported', 5),
#   ('spending', 5),
#   ('pace', 5),
#   ('q4', 4),
#   ('capital', 4),
#   ('remain', 4),
#   ('expanded', 4),
#   ('sectors', 4),
#   ('investment', 4),
#   ('major', 4),
#   ('public', 4),
#   ('economy', 4),
#   ('consumption', 4),
#   ('economies', 4),
#   ('global', 4)],
#  'broad money grows a steady 3 in december': [('growth', 8),
#   ('loans', 4),
#   ('banking', 4),
#   ('expansion', 3),
#   ('november', 3),
#   ('net', 3),
#   ('driven', 3),
#   ('outstanding', 3),
#   ('december', 3),
#   ('annual', 3),
#   ('loan', 2),
#   ('households', 2),
#   ('slightly', 2),
#   ('amid', 2),
#   ('sector', 2),
#   ('stable', 2),
#   ('private', 2),
#   ('recorded', 2),
#   ('m3', 2),
#   ('continued', 2),
#   ('higher', 2),
#   ('rm299bil', 1),
#   ('rm293bil', 1),
#   ('grew', 1),
#   ('extended', 1),
#   ('purchase', 1),
#   ('monthoutstanding', 1),
#   ('monthnet', 1),
#   ('month', 1),
#   ('corporate', 1)],
#  'banking systems outstanding business loans up 5 in december': [('growth', 8),
#   ('december', 8),
#   ('november', 5),
#   ('loans', 5),
#   ('net', 4),
#   ('recorded', 4),
#   ('outstanding', 4),
#   ('said', 4),
#   ('banking', 4),
#   ('month', 3),
#   ('slightly', 3),
#   ('business', 3),
#   ('annual', 3),
#   ('sectors', 3),
#   ('expansion', 3),
#   ('households', 3),
#   ('stable', 3),
#   ('loan', 3),
#   ('continued', 2),
#   ('money', 2),
#   ('broad', 2),
#   ('higher', 2),
#   ('sector', 2),
#   ('tuesday', 2),
#   ('driven', 2),
#   ('corporate', 2),
#   ('private', 2),
#   ('decline', 2),
#   ('issuances', 2),
#   ('moderation', 2)],
#  'bank negara issues draft on credit risk management': [('risk', 8),
#   ('bank', 6),
#   ('requirements', 5),
#   ('credit', 5),
#   ('management', 5),
#   ('financial', 4),
#   ('central', 3),
#   ('proposals', 3),
#   ('institutions', 3),
#   ('key', 2),
#   ('regulatory', 2),
#   ('draft', 2),
#   ('effective', 2),
#   ('written', 2),
#   ('expectations', 2),
#   ('negara', 2),
#   ('governance', 2),
#   ('exposure', 2),
#   ('added', 2),
#   ('said', 2),
#   ('feedback', 2),
#   ('areas', 2),
#   ('proposed', 2),
#   ('licensed', 1),
#   ('set', 1),
#   ('negaras', 1),
#   ('exceptional', 1),
#   ('prescribed', 1),
#   ('uncertainty', 1),
#   ('concentration', 1)],
#  'broad money growth falls in november': [('growth', 10),
#   ('october', 6),
#   ('loans', 5),
#   ('outstanding', 5),
#   ('net', 4),
#   ('november', 4),
#   ('banking', 4),
#   ('driven', 3),
#   ('higher', 3),
#   ('continued', 3),
#   ('expansion', 3),
#   ('annual', 3),
#   ('month', 3),
#   ('loan', 2),
#   ('private', 2),
#   ('households', 2),
#   ('54', 2),
#   ('29', 2),
#   ('amid', 2),
#   ('sector', 2),
#   ('m3', 2),
#   ('islamic', 1),
#   ('stable', 1),
#   ('decline', 1),
#   ('overall', 1),
#   ('foreign', 1),
#   ('residential', 1),
#   ('registered', 1),
#   ('increase', 1),
#   ('rm69il', 1)],
#  'fuming over unjust fees': [('financial', 10),
#   ('pay', 8),
#   ('services', 6),
#   ('charge', 6),
#   ('fee', 6),
#   ('bank', 5),
#   ('psc', 5),
#   ('consumers', 5),
#   ('ofs', 5),
#   ('banks', 5),
#   ('disputes', 4),
#   ('charges', 4),
#   ('paying', 4),
#   ('card', 4),
#   ('airports', 4),
#   ('insurance', 3),
#   ('travellers', 3),
#   ('mavcom', 3),
#   ('consumer', 3),
#   ('banking', 3),
#   ('make', 3),
#   ('did', 3),
#   ('rm1', 3),
#   ('customers', 3),
#   ('service', 3),
#   ('loan', 3),
#   ('security', 3),
#   ('airport', 2),
#   ('2013', 2),
#   ('upgrade', 2)],
#  'ombudsman for financial services starts oct 1': [('financial', 23),
#   ('ombudsman', 16),
#   ('services', 12),
#   ('disputes', 6),
#   ('consumers', 5),
#   ('said', 5),
#   ('scheme', 4),
#   ('payment', 3),
#   ('bnm', 3),
#   ('takaful', 3),
#   ('insurance', 3),
#   ('act', 2),
#   ('independent', 2),
#   ('court', 2),
#   ('bank', 2),
#   ('involving', 2),
#   ('eligible', 2),
#   ('number', 2),
#   ('2013', 2),
#   ('fair', 2),
#   ('lumpur', 2),
#   ('service', 2),
#   ('malaysia', 2),
#   ('resolve', 2),
#   ('providers', 2),
#   ('resolution', 2),
#   ('dispute', 2),
#   ('kuala', 2),
#   ('level', 1),
#   ('independence', 1)],
#  'cooperative bank for personal financing': [('bank', 16),
#   ('rakyat', 7),
#   ('bhd', 5),
#   ('malaysia', 5),
#   ('financial', 3),
#   ('cooperative', 3),
#   ('key', 2),
#   ('personal', 2),
#   ('falls', 2),
#   ('set', 2),
#   ('negara', 2),
#   ('simpanan', 2),
#   ('institutions', 2),
#   ('civil', 2),
#   ('dfis', 2),
#   ('ser', 1),
#   ('agrobankamong', 1),
#   ('cooperatives', 1),
#   ('generally', 1),
#   ('pertanian', 1),
#   ('bad', 1),
#   ('cing', 1),
#   ('trade', 1),
#   ('focuses', 1),
#   ('pembangunan', 1),
#   ('jurisdiction', 1),
#   ('come', 1),
#   ('small', 1),
#   ('services', 1),
#   ('looks', 1)],
#  'm3 grows 23 in july says bank negara': [('month', 5),
#   ('said', 5),
#   ('bnm', 4),
#   ('july', 4),
#   ('net', 4),
#   ('growth', 4),
#   ('continued', 4),
#   ('ratio', 3),
#   ('banking', 3),
#   ('capital', 3),
#   ('average', 2),
#   ('equity', 2),
#   ('ringgit', 2),
#   ('private', 2),
#   ('mainly', 2),
#   ('bank', 2),
#   ('m3', 2),
#   ('tier', 2),
#   ('june', 2),
#   ('annual', 2),
#   ('portfolio', 2),
#   ('sector', 2),
#   ('increase', 2),
#   ('amid', 2),
#   ('driven', 2),
#   ('expansion', 2),
#   ('rates', 2),
#   ('crude', 2),
#   ('foreign', 1),
#   ('143', 1)],
#  'auditors find it tough to unmask corporate fraud': [('fraud', 21),
#   ('corporate', 16),
#   ('says', 9),
#   ('companies', 8),
#   ('malaysia', 7),
#   ('heng', 7),
#   ('report', 6),
#   ('bhd', 6),
#   ('1mdb', 6),
#   ('say', 6),
#   ('financial', 6),
#   ('people', 5),
#   ('years', 5),
#   ('year', 4),
#   ('creative', 4),
#   ('detect', 4),
#   ('gerald', 4),
#   ('comes', 4),
#   ('corruption', 4),
#   ('activities', 4),
#   ('involved', 4),
#   ('act', 4),
#   ('case', 4),
#   ('auditors', 4),
#   ('accounting', 4),
#   ('suit', 4),
#   ('country', 3),
#   ('scandal', 3),
#   ('commission', 3),
#   ('committed', 3)],
#  'broad money growth at 19 in june says bnm': [('loans', 6),
#   ('growth', 5),
#   ('loan', 4),
#   ('ratio', 4),
#   ('banking', 4),
#   ('capital', 3),
#   ('continued', 3),
#   ('said', 3),
#   ('money', 3),
#   ('net', 3),
#   ('month', 3),
#   ('households', 2),
#   ('tier', 2),
#   ('lower', 2),
#   ('sector', 2),
#   ('private', 2),
#   ('compared', 2),
#   ('deposits', 2),
#   ('mainly', 2),
#   ('bnm', 2),
#   ('financial', 2),
#   ('annual', 2),
#   ('equity', 2),
#   ('m3', 2),
#   ('june', 2),
#   ('july', 2),
#   ('bank', 2),
#   ('outstanding', 2),
#   ('institutions', 2),
#   ('moderation', 2)],
#  'cgc targets rm145bil sme loan base by 2020': [('smes', 7),
#   ('sme', 7),
#   ('financing', 5),
#   ('year', 4),
#   ('rate', 4),
#   ('base', 3),
#   ('mohd', 3),
#   ('firm', 3),
#   ('plan', 3),
#   ('partner', 3),
#   ('cgcs', 3),
#   ('awards', 3),
#   ('f1', 3),
#   ('islamic', 3),
#   ('guarantee', 3),
#   ('graduation', 3),
#   ('guarantees', 3),
#   ('said', 3),
#   ('bhd', 3),
#   ('banks', 3),
#   ('bank', 3),
#   ('loan', 3),
#   ('cgc', 3),
#   ('asset', 2),
#   ('contributions', 2),
#   ('ocbc', 2),
#   ('alamin', 2),
#   ('fiveyear', 2),
#   ('years', 2),
#   ('overall', 2)],
#  'alternative financing beckons': [('smes', 10),
#   ('business', 9),
#   ('vcs', 6),
#   ('funds', 6),
#   ('alternative', 6),
#   ('said', 5),
#   ('businesses', 5),
#   ('investors', 5),
#   ('small', 5),
#   ('companies', 5),
#   ('foo', 5),
#   ('development', 4),
#   ('proposal', 4),
#   ('looking', 4),
#   ('financial', 4),
#   ('equity', 4),
#   ('financing', 4),
#   ('venture', 3),
#   ('crowd', 3),
#   ('funding', 3),
#   ('proposals', 3),
#   ('crowdfunding', 3),
#   ('director', 3),
#   ('credit', 3),
#   ('chung', 3),
#   ('high', 2),
#   ('noted', 2),
#   ('just', 2),
#   ('choo', 2),
#   ('seminar', 2)],
#  'malaysia is weathering the economic storm with bold measures': [('government',
#    9),
#   ('tax', 6),
#   ('cut', 6),
#   ('expenditure', 6),
#   ('revenue', 6),
#   ('measures', 5),
#   ('economy', 5),
#   ('oil', 4),
#   ('did', 3),
#   ('fiscal', 3),
#   ('public', 3),
#   ('benefit', 3),
#   ('gst', 3),
#   ('budget', 3),
#   ('countrys', 3),
#   ('rm9bil', 3),
#   ('2016', 3),
#   ('2015', 3),
#   ('million', 2),
#   ('price', 2),
#   ('epf', 2),
#   ('fund', 2),
#   ('gap', 2),
#   ('workforce', 2),
#   ('reduced', 2),
#   ('rm8bil', 2),
#   ('targets', 2),
#   ('high', 2),
#   ('taxpayers', 2),
#   ('operating', 2)],
#  'briefs': [('said', 10),
#   ('government', 7),
#   ('companies', 7),
#   ('chapter', 6),
#   ('malaysia', 6),
#   ('smes', 6),
#   ('ecommerce', 5),
#   ('tppa', 5),
#   ('growth', 4),
#   ('chan', 4),
#   ('procurement', 4),
#   ('funding', 3),
#   ('online', 3),
#   ('policies', 3),
#   ('financial', 3),
#   ('participation', 3),
#   ('trade', 3),
#   ('tpp', 3),
#   ('minister', 3),
#   ('bumiputera', 3),
#   ('market', 3),
#   ('strong', 2),
#   ('rm6bil', 2),
#   ('international', 2),
#   ('threshold', 2),
#   ('economy', 2),
#   ('seri', 2),
#   ('include', 2),
#   ('prime', 2),
#   ('measures', 2)],
#  'dealing with hard times': [('budget', 16),
#   ('economic', 14),
#   ('2016', 13),
#   ('growth', 10),
#   ('oil', 9),
#   ('government', 8),
#   ('measures', 7),
#   ('year', 7),
#   ('prices', 7),
#   ('crude', 7),
#   ('barrel', 7),
#   ('spending', 6),
#   ('new', 6),
#   ('recalibrated', 6),
#   ('private', 6),
#   ('development', 6),
#   ('explains', 5),
#   ('research', 5),
#   ('manokaran', 5),
#   ('remains', 5),
#   ('remain', 5),
#   ('says', 5),
#   ('support', 5),
#   ('malaysia', 5),
#   ('consumption', 4),
#   ('domestic', 4),
#   ('depressed', 4),
#   ('governments', 4),
#   ('malaysias', 4),
#   ('countrys', 4)],
#  'welcome news for smes and startups': [('smes', 5),
#   ('capital', 5),
#   ('venture', 4),
#   ('said', 4),
#   ('economic', 3),
#   ('prime', 3),
#   ('funds', 3),
#   ('business', 3),
#   ('startups', 3),
#   ('wee', 2),
#   ('enterprises', 2),
#   ('rm6bil', 2),
#   ('announcement', 2),
#   ('government', 2),
#   ('ministers', 2),
#   ('development', 2),
#   ('help', 2),
#   ('agencies', 2),
#   ('budget', 2),
#   ('dr', 2),
#   ('datuk', 2),
#   ('international', 2),
#   ('seri', 2),
#   ('malaysia', 2),
#   ('investing', 1),
#   ('investment', 1),
#   ('believed', 1),
#   ('investors', 1),
#   ('creation', 1),
#   ('expansion', 1)],
#  'budget 2016 revision several key measures to be taken': [('increase', 3),
#   ('government', 3),
#   ('including', 3),
#   ('development', 3),
#   ('reduce', 3),
#   ('benefit', 2),
#   ('budget', 2),
#   ('2016', 2),
#   ('month', 2),
#   ('management', 2),
#   ('workers', 2),
#   ('income', 2),
#   ('contributions', 2),
#   ('foreign', 2),
#   ('spending', 2),
#   ('implement', 1),
#   ('putrajaya', 1),
#   ('liberalise', 1),
#   ('prime', 1),
#   ('dec', 1),
#   ('people', 1),
#   ('beans', 1),
#   ('supplies', 1),
#   ('rm2000', 1),
#   ('speech', 1),
#   ('enforcement', 1),
#   ('senior', 1),
#   ('relief', 1),
#   ('capital', 1),
#   ('update', 1)],
#  'budget 2016 revision full text of pms speech': [('government', 61),
#   ('economic', 33),
#   ('2016', 20),
#   ('economy', 19),
#   ('rakyat', 18),
#   ('budget', 16),
#   ('measure', 15),
#   ('measures', 15),
#   ('global', 13),
#   ('billion', 13),
#   ('programme', 12),
#   ('domestic', 11),
#   ('prices', 11),
#   ('oil', 11),
#   ('continue', 11),
#   ('2015', 10),
#   ('nation', 10),
#   ('increase', 9),
#   ('programmes', 9),
#   ('year', 9),
#   ('1malaysia', 9),
#   ('growth', 9),
#   ('challenges', 8),
#   ('private', 8),
#   ('crude', 8),
#   ('addition', 8),
#   ('gdp', 8),
#   ('current', 8),
#   ('foreign', 7),
#   ('initiatives', 7)],
#  'najib presents revised 2016 budget': [('budget', 7),
#   ('said', 6),
#   ('government', 6),
#   ('2016', 6),
#   ('najib', 5),
#   ('economic', 5),
#   ('global', 5),
#   ('measures', 4),
#   ('increase', 4),
#   ('benefit', 3),
#   ('growth', 3),
#   ('capital', 3),
#   ('including', 3),
#   ('price', 3),
#   ('development', 3),
#   ('expected', 3),
#   ('barrel', 3),
#   ('reduce', 3),
#   ('countrys', 3),
#   ('oil', 3),
#   ('tppa', 2),
#   ('proactive', 2),
#   ('economy', 2),
#   ('month', 2),
#   ('trade', 2),
#   ('financial', 2),
#   ('services', 2),
#   ('national', 2),
#   ('agenda', 2),
#   ('plans', 2)],
#  'cgc to develop credit guarantee framework for smes in rwanda': [('cgc', 13),
#   ('bdf', 8),
#   ('development', 8),
#   ('rwanda', 7),
#   ('countries', 6),
#   ('guarantee', 6),
#   ('said', 6),
#   ('credit', 5),
#   ('smes', 5),
#   ('sme', 4),
#   ('mohd', 4),
#   ('share', 3),
#   ('zamree', 3),
#   ('visits', 3),
#   ('study', 3),
#   ('expertise', 3),
#   ('malaysia', 3),
#   ('mou', 3),
#   ('east', 2),
#   ('assistance', 2),
#   ('institutions', 2),
#   ('executive', 2),
#   ('framework', 2),
#   ('cgcs', 2),
#   ('financing', 2),
#   ('mandate', 2),
#   ('middle', 2),
#   ('kuala', 2),
#   ('officer', 2),
#   ('chief', 2)],
#  'bank negara enhances consumer protection in disputes involving banks and insurers': [('fos',
#    14),
#   ('financial', 11),
#   ('services', 5),
#   ('ombudsman', 5),
#   ('resolution', 4),
#   ('consumers', 4),
#   ('islamic', 4),
#   ('fsps', 4),
#   ('banks', 3),
#   ('approved', 3),
#   ('disputes', 3),
#   ('scheme', 3),
#   ('review', 3),
#   ('bank', 3),
#   ('dispute', 3),
#   ('regulations', 3),
#   ('improve', 2),
#   ('designated', 2),
#   ('said', 2),
#   ('advisers', 2),
#   ('process', 2),
#   ('agreement', 2),
#   ('payment', 2),
#   ('instrument', 2),
#   ('public', 2),
#   ('directors', 2),
#   ('issuers', 2),
#   ('decision', 2),
#   ('negara', 2),
#   ('2015', 2)],
#  'access for smes to bnms special funds channel': [('smes', 6),
#   ('funds', 5),
#   ('financing', 5),
#   ('bhd', 4),
#   ('bnm', 4),
#   ('bank', 4),
#   ('development', 4),
#   ('small', 4),
#   ('medium', 3),
#   ('said', 3),
#   ('malaysia', 3),
#   ('institutions', 3),
#   ('financial', 3),
#   ('years', 3),
#   ('access', 2),
#   ('operation', 2),
#   ('banks', 2),
#   ('maximum', 2),
#   ('exceed', 2),
#   ('seven', 2),
#   ('participating', 2),
#   ('rates', 2),
#   ('companies', 2),
#   ('special', 2),
#   ('pfis', 1),
#   ('islamic', 1),
#   ('consider', 1),
#   ('increase', 1),
#   ('fsmi2', 1),
#   ('business', 1)],
#  'govt denies us150mil loan given to 1mdb was to purchase land in pulau indah': [('loan',
#    6),
#   ('bank', 4),
#   ('exim', 4),
#   ('1mdbs', 3),
#   ('1mdb', 3),
#   ('support', 3),
#   ('government', 3),
#   ('overseas', 3),
#   ('said', 3),
#   ('import', 2),
#   ('power', 2),
#   ('deputy', 2),
#   ('given', 2),
#   ('mandate', 2),
#   ('information', 2),
#   ('chua', 2),
#   ('minister', 2),
#   ('markets', 2),
#   ('letter', 2),
#   ('datuk', 2),
#   ('confirmed', 2),
#   ('line', 2),
#   ('export', 2),
#   ('ahmad', 2),
#   ('plants', 2),
#   ('development', 2),
#   ('finance', 2),
#   ('maintenance', 1),
#   ('us150mil', 1),
#   ('funding', 1)],
#  'breaking down barriers to financing': [('said', 12),
#   ('entrepreneurs', 11),
#   ('business', 10),
#   ('bankers', 9),
#   ('teoh', 7),
#   ('smes', 7),
#   ('forum', 5),
#   ('loan', 5),
#   ('bank', 5),
#   ('koong', 5),
#   ('banks', 4),
#   ('cedar', 4),
#   ('entrepreneur', 4),
#   ('development', 4),
#   ('plan', 4),
#   ('loans', 4),
#   ('funds', 3),
#   ('institutions', 3),
#   ('prepare', 3),
#   ('financial', 3),
#   ('try', 3),
#   ('sme', 3),
#   ('training', 3),
#   ('money', 3),
#   ('credit', 3),
#   ('help', 3),
#   ('manpower', 2),
#   ('capacity', 2),
#   ('centre', 2),
#   ('include', 2)],
#  'china japan finance ministers concerned about volatile commodity prices': [('finance',
#    3),
#   ('global', 3),
#   ('economy', 2),
#   ('volatile', 2),
#   ('prices', 2),
#   ('beijing', 2),
#   ('concerns', 2),
#   ('infrastructure', 2),
#   ('said', 2),
#   ('development', 2),
#   ('minister', 2),
#   ('sides', 2),
#   ('economic', 2),
#   ('commodity', 2),
#   ('statement', 2),
#   ('profound', 1),
#   ('asian', 1),
#   ('spillover', 1),
#   ('japan', 1),
#   ('launched', 1),
#   ('japanese', 1),
#   ('meeting', 1),
#   ('bank', 1),
#   ('dangers', 1),
#   ('jiwei', 1),
#   ('following', 1),
#   ('chinese', 1),
#   ('asia', 1),
#   ('chinaled', 1),
#   ('china', 1)],
#  'boost for chinese smes': [('loans', 9),
#   ('smes', 8),
#   ('said', 6),
#   ('businesses', 6),
#   ('loan', 6),
#   ('financial', 4),
#   ('wee', 4),
#   ('kojadi', 4),
#   ('working', 3),
#   ('years', 3),
#   ('fund', 3),
#   ('applicants', 2),
#   ('banks', 2),
#   ('asking', 2),
#   ('application', 2),
#   ('siong', 2),
#   ('budget', 2),
#   ('fee', 2),
#   ('financing', 2),
#   ('institutions', 2),
#   ('set', 2),
#   ('business', 2),
#   ('disbursed', 2),
#   ('payment', 2),
#   ('dr', 2),
#   ('expand', 2),
#   ('ka', 2),
#   ('datuk', 2),
#   ('borrow', 2),
#   ('added', 2)],
#  'smebiz briefs': [('banks', 8),
#   ('sme', 7),
#   ('islamic', 7),
#   ('development', 6),
#   ('finance', 5),
#   ('bank', 5),
#   ('smes', 4),
#   ('banker', 4),
#   ('said', 4),
#   ('business', 4),
#   ('companies', 3),
#   ('malaysia', 3),
#   ('prices', 3),
#   ('financial', 3),
#   ('lending', 3),
#   ('programme', 3),
#   ('outstanding', 3),
#   ('banking', 3),
#   ('economic', 3),
#   ('chinese', 3),
#   ('chartered', 3),
#   ('china', 3),
#   ('chin', 3),
#   ('gulf', 2),
#   ('produce', 2),
#   ('association', 2),
#   ('promotion', 2),
#   ('certification', 2),
#   ('small', 2),
#   ('result', 2)],
#  'plenty of funding for smes cgc': [('smes', 11),
#   ('financial', 8),
#   ('financing', 7),
#   ('loans', 6),
#   ('cgc', 6),
#   ('institutions', 5),
#   ('small', 4),
#   ('kong', 4),
#   ('products', 4),
#   ('hong', 4),
#   ('available', 4),
#   ('hon', 4),
#   ('businesses', 4),
#   ('malaysia', 4),
#   ('sme', 3),
#   ('financiers', 3),
#   ('need', 3),
#   ('proper', 3),
#   ('different', 3),
#   ('schemes', 3),
#   ('development', 3),
#   ('bank', 3),
#   ('lack', 3),
#   ('scheme', 3),
#   ('says', 3),
#   ('particularly', 3),
#   ('guarantee', 3),
#   ('direct', 2),
#   ('know', 2),
#   ('collateral', 2)],
#  'rm32bil remitted by foreign workers last year': [('money', 7),
#   ('said', 4),
#   ('country', 3),
#   ('licensed', 3),
#   ('act', 3),
#   ('services', 3),
#   ('chua', 3),
#   ('datuk', 2),
#   ('remit', 2),
#   ('question', 2),
#   ('financial', 2),
#   ('changers', 2),
#   ('institutions', 2),
#   ('total', 2),
#   ('countries', 2),
#   ('business', 2),
#   ('funds', 2),
#   ('government', 2),
#   ('remitted', 2),
#   ('invert', 1),
#   ('deputy', 1),
#   ('license', 1),
#   ('43', 1),
#   ('mansor', 1),
#   ('various', 1),
#   ('development', 1),
#   ('31', 1),
#   ('workers', 1),
#   ('rm361mil', 1),
#   ('rm134bil', 1)],
#  'bank negara completes public consultation on dfi': [('consultation', 3),
#   ('requirements', 3),
#   ('dfi', 3),
#   ('criteria', 3),
#   ('bank', 3),
#   ('development', 2),
#   ('management', 2),
#   ('negara', 2),
#   ('business', 2),
#   ('dfia', 2),
#   ('proper', 2),
#   ('feedback', 2),
#   ('financial', 2),
#   ('public', 2),
#   ('central', 2),
#   ('institutions', 2),
#   ('representations', 1),
#   ('disclosure', 1),
#   ('various', 1),
#   ('bernamabank', 1),
#   ('appointment', 1),
#   ('agencies', 1),
#   ('corporate', 1),
#   ('trade', 1),
#   ('online', 1),
#   ('focus', 1),
#   ('mandated', 1),
#   ('activitiesthe', 1),
#   ('undertaking', 1),
#   ('permitted', 1)],
#  'bnm completes public consultation on dfi management criteria': [('requirements',
#    3),
#   ('bank', 3),
#   ('feedback', 2),
#   ('dfia', 2),
#   ('proper', 2),
#   ('criteria', 2),
#   ('development', 2),
#   ('consultation', 2),
#   ('institutions', 2),
#   ('financial', 2),
#   ('bnm', 2),
#   ('dfi', 2),
#   ('central', 2),
#   ('business', 2),
#   ('sectors', 2),
#   ('corporate', 1),
#   ('appointments', 1),
#   ('public', 1),
#   ('online', 1),
#   ('lumpur', 1),
#   ('various', 1),
#   ('statement', 1),
#   ('management', 1),
#   ('activities', 1),
#   ('support', 1),
#   ('subsidiaries', 1),
#   ('bernama', 1),
#   ('responses', 1),
#   ('received', 1),
#   ('submitted', 1)],
#  'rm893mil to be set aside under budget 2015 for flood mitigation projects': [('government',
#    5),
#   ('loan', 5),
#   ('months', 4),
#   ('said', 4),
#   ('najib', 3),
#   ('financial', 3),
#   ('development', 3),
#   ('floods', 3),
#   ('flood', 3),
#   ('areas', 2),
#   ('recent', 2),
#   ('financing', 2),
#   ('special', 2),
#   ('added', 2),
#   ('kelantan', 2),
#   ('repayments', 2),
#   ('relief', 2),
#   ('aim', 2),
#   ('rm500mil', 2),
#   ('sme', 2),
#   ('houses', 2),
#   ('set', 2),
#   ('situation', 2),
#   ('malaysia', 2),
#   ('floodaffected', 2),
#   ('affected', 2),
#   ('initial', 2),
#   ('infrastructure', 2),
#   ('guarantee', 2),
#   ('provided', 2)],
#  'budget revision full text of prime ministers speech': [('oil', 31),
#   ('government', 26),
#   ('2015', 23),
#   ('prices', 21),
#   ('crude', 21),
#   ('economic', 17),
# ...
#   ('institutions', 2),
#   ('financing', 2),
#   ('capital', 2),
#   ('banks', 2),
#   ('guarantee', 2),
#   ('product', 2),
#   ('financial', 2),
#   ('pfis', 2),
#   ('aimed', 2),
#   ('exim', 2),
#   ('rm1bil', 2),
#   ('value', 2),
#   ('wings', 1),
#   ('construction', 1),
#   ('customers', 1),
#   ('services', 1),
#   ('spur', 1),
#   ('loan', 1),
#   ('consultancy', 1),
#   ('development', 1),
#   ('expanding', 1)],
#  'exim bank to gain from merger': [('year', 13),
#   ('bank', 10),
#   ('said', 7),
#   ('kamal', 6),
#   ('new', 6),
#   ('banks', 5),
#   ('exim', 5),
#   ('profit', 4),
#   ('facility', 4),
#   ('net', 4),
#   ('east', 3),
#   ('confident', 3),
#   ('financial', 3),
#   ('31', 3),
#   ('overseas', 3),
#   ('ending', 3),
#   ('export', 3),
#   ('financing', 3),
#   ('products', 3),
#   ('services', 3),
#   ('exporter', 3),
#   ('dec', 3),
#   ('malaysia', 2),
#   ('development', 2),
#   ('years', 2),
#   ('malaysiakitchen', 2),
#   ('indirect', 2),
#   ('ali', 2),
#   ('branches', 2),
#   ('policy', 2)],
#  'bank ma rules eased': [('bank', 8),
#   ('said', 7),
#   ('act', 5),
#   ('financial', 4),
#   ('negara', 4),
#   ('banking', 3),
#   ('talks', 3),
#   ('banks', 3),
#   ('ruling', 3),
#   ('bhd', 3),
#   ('institutions', 3),
#   ('competition', 2),
#   ('simultaneously', 2),
#   ('shareholders', 2),
#   ('partner', 2),
#   ('change', 2),
#   ('abdul', 2),
#   ('new', 2),
#   ('pricing', 2),
#   ('positive', 2),
#   ('mas', 2),
#   ('negotiations', 2),
#   ('parties', 2),
#   ('better', 2),
#   ('result', 2),
#   ('hamidy', 1),
#   ('amresearch', 1),
#   ('jaya', 1),
#   ('sends', 1),
#   ('takaful', 1)],
#  'foreign currency denominated bonds allowed in malaysia': [('financial', 12),
#   ('malaysia', 9),
#   ('centre', 9),
#   ('mifc', 7),
#   ('foreign', 7),
#   ('islamic', 7),
#   ('banks', 6),
#   ('development', 6),
#   ('negara', 5),
#   ('bank', 5),
#   ('market', 5),
#   ('issuers', 5),
#   ('dialogue', 5),
#   ('bonds', 5),
#   ('malaysian', 4),
#   ('institutions', 4),
#   ('multilateral', 4),
#   ('resident', 4),
#   ('initiatives', 4),
#   ('international', 4),
#   ('address', 4),
#   ('keynote', 3),
#   ('currency', 3),
#   ('origination', 3),
#   ('sukuks', 3),
#   ('regulators', 3),
#   ('denominated', 3),
#   ('mncs', 3),
#   ('said', 3),
#   ('industry', 3)],
#  'razif is deputy governor of bank negara': [('bank', 8),
#   ('razif', 5),
#   ('datuk', 4),
#   ('negara', 4),
#   ('islamic', 3),
#   ('governor', 3),
#   ('abdul', 3),
#   ('finance', 3),
#   ('deputy', 3),
#   ('financial', 3),
#   ('central', 3),
#   ('mohd', 2),
#   ('development', 2),
#   ('tenure', 2),
#   ('1999', 2),
#   ('minister', 2),
#   ('said', 2),
#   ('term', 2),
#   ('board', 2),
#   ('effect', 2),
#   ('threeyear', 2),
#   ('appointment', 2),
#   ('services', 2),
#   ('representative', 2),
#   ('banking', 2),
#   ('june', 2),
#   ('kadir', 2),
#   ('regulation', 2),
#   ('enterprises', 1),
#   ('negaras', 1)],
#  'cgc eyes rm4b loan portfolio': [('loans', 12),
#   ('wan', 10),
#   ('azhar', 8),
#   ('said', 7),
#   ('banks', 5),
#   ('portfolio', 5),
#   ('year', 5),
#   ('sme', 5),
#   ('cgc', 5),
#   ('smes', 4),
#   ('institutions', 4),
#   ('financial', 4),
#   ('award', 3),
#   ('bhd', 3),
#   ('smi', 3),
#   ('malaysia', 3),
#   ('new', 3),
#   ('rates', 3),
#   ('number', 3),
#   ('company', 3),
#   ('companies', 3),
#   ('bank', 3),
#   ('datuk', 2),
#   ('plans', 2),
#   ('entrants', 2),
#   ('ahmad', 2),
#   ('guarantee', 2),
#   ('borrowers', 2),
#   ('won', 2),
#   ('value', 2)],
#  'good showing by development financial institutions': [('loans', 11),
#   ('dfis', 9),
#   ('total', 9),
#   ('bank', 5),
#   ('outstanding', 4),
#   ('extended', 4),
#   ('credit', 4),
#   ('higher', 4),
#   ('sectors', 3),
#   ('negara', 3),
#   ('growth', 3),
#   ('strong', 3),
#   ('2004', 3),
#   ('financing', 3),
#   ('guarantee', 2),
#   ('end2005', 2),
#   ('bhd', 2),
#   ('increase', 2),
#   ('click', 2),
#   ('296', 2),
#   ('account', 2),
#   ('end2004', 2),
#   ('end', 2),
#   ('consumption', 2),
#   ('activities', 2),
#   ('rm161bil', 1),
#   ('deposits', 1),
#   ('rm335bil', 1),
#   ('amounted', 1),
#   ('rm377bil', 1)],
#  'bpimb pretax profit up 19 to rm381mil': [('loans', 8),
#   ('total', 7),
#   ('2003', 4),
#   ('approved', 3),
#   ('year', 3),
#   ('industry', 3),
#   ('12', 3),
#   ('loan', 2),
#   ('increase', 2),
#   ('net', 2),
#   ('smes', 2),
#   ('rose', 2),
#   ('strong', 2),
#   ('rm16bil', 2),
#   ('increased', 2),
#   ('said', 2),
#   ('bank', 2),
#   ('valued', 2),
#   ('scheme', 2),
#   ('223', 1),
#   ('mainly', 1),
#   ('31', 1),
#   ('rm29bil', 1),
#   ('executive', 1),
#   ('showing', 1),
#   ('218', 1),
#   ('225', 1),
#   ('institutions', 1),
#   ('rm3204mil', 1),
#   ('compared', 1)],
#  'financial system rich in assets': [('financial', 9),
#   ('assets', 8),
#   ('banks', 7),
#   ('total', 7),
#   ('share', 7),
#   ('2004', 7),
#   ('year', 6),
#   ('insurance', 5),
#   ('institutions', 4),
#   ('grew', 4),
#   ('securities', 4),
#   ('loans', 4),
#   ('commercial', 4),
#   ('advances', 4),
#   ('banking', 4),
#   ('increased', 4),
#   ('provident', 3),
#   ('pension', 3),
#   ('finance', 3),
#   ('largest', 3),
#   ('holding', 3),
#   ('remained', 3),
#   ('investment', 3),
#   ('lending', 3),
#   ('funds', 3),
#   ('companies', 3),
#   ('growth', 2),
#   ('asset', 2),
#   ('gross', 2),
#   ('rose', 2)],
#  'development financing activities stepped up': [('bank', 11),
#   ('total', 10),
#   ('loans', 10),
#   ('bhd', 8),
#   ('malaysia', 8),
#   ('outstanding', 7),
#   ('financing', 6),
#   ('dfis', 6),
#   ('infrastructure', 5),
#   ('sector', 5),
#   ('sectors', 4),
#   ('credit', 4),
#   ('growth', 4),
#   ('respectively', 4),
#   ('rose', 4),
#   ('mobilised', 3),
#   ('accounting', 3),
#   ('pembangunan', 3),
#   ('institutions', 3),
#   ('government', 3),
#   ('financial', 3),
#   ('smes', 3),
#   ('consumption', 2),
#   ('accounted', 2),
#   ('increasing', 2),
#   ('enterprises', 2),
#   ('higher', 2),
#   ('construction', 2),
#   ('operations', 2),
#   ('bumiputra', 2)],
#  'basic banking services at minimal cost from february': [('said', 14),
#   ('financial', 14),
#   ('fmb', 11),
#   ('institutions', 8),
#   ('banking', 7),
#   ('zeti', 7),
#   ('services', 7),
#   ('insurance', 6),
#   ('bank', 6),
#   ('consumers', 5),
#   ('consumer', 4),
#   ('bureau', 4),
#   ('negara', 4),
#   ('sri', 4),
#   ('tan', 4),
#   ('banks', 4),
#   ('charge', 3),
#   ('guidelines', 3),
#   ('provide', 3),
#   ('basic', 3),
#   ('time', 3),
#   ('haidar', 3),
#   ('cards', 3),
#   ('resolution', 3),
#   ('launch', 3),
#   ('cases', 3),
#   ('products', 3),
#   ('alternative', 2),
#   ('mediation', 2),
#   ('costs', 2)],
#  'tax refund procedure made easier': [('tax', 13),
#   ('duty', 12),
#   ('increase', 9),
#   ('budget', 8),
#   ('building', 8),
#   ('refund', 7),
#   ('fund', 7),
#   ('excise', 6),
#   ('act', 6),
#   ('allowance', 6),
#   ('2005', 6),
#   ('finance', 6),
#   ('used', 6),
#   ('construction', 5),
#   ('industrial', 5),
#   ('change', 5),
#   ('claim', 5),
#   ('purchase', 5),
#   ('benefit', 5),
#   ('companies', 4),
#   ('income', 4),
#   ('company', 4),
#   ('import', 4),
#   ('cigarettes', 4),
#   ('acquirer', 4),
#   ('proposed', 4),
#   ('iba', 4),
#   ('minister', 4),
#   ('increased', 3),
#   ('passed', 3)],
#  'reshaping bank industri': [('bank', 34),
#   ('industri', 15),
#   ('capital', 14),
#   ('says', 12),
#   ('banks', 11),
#   ('othman', 11),
#   ('bhd', 8),
#   ('rwcr', 7),
#   ('time', 6),
#   ('industries', 6),
#   ('ratio', 6),
#   ('malaysia', 6),
#   ('lending', 5),
#   ('banking', 5),
#   ('injection', 5),
#   ('commercial', 5),
#   ('development', 5),
#   ('financial', 5),
#   ('shipping', 5),
#   ('business', 5),
#   ('government', 5),
#   ('restructuring', 4),
#   ('strategic', 4),
#   ('subsidiaries', 4),
#   ('measurement', 3),
#   ('ram', 3),
#   ('different', 3),
#   ('dfi', 3),
#   ('countrys', 3),
#   ('investments', 3)],
#  'meps in atm tieup with artajasa': [('meps', 11),
#   ('bank', 9),
#   ('rakyat', 6),
#   ('atm', 6),
#   ('datuk', 4),
#   ('said', 4),
#   ('alim', 3),
#   ('atms', 3),
#   ('services', 3),
#   ('network', 3),
#   ('cardholders', 3),
#   ('artajasa', 3),
#   ('electronic', 3),
#   ('mohd', 3),
#   ('indonesia', 2),
#   ('crossborder', 2),
#   ('yesterday', 2),
#   ('banking', 2),
#   ('banks', 2),
#   ('ariffin', 2),
#   ('bhd', 2),
#   ('lumpur', 2),
#   ('malaysia', 2),
#   ('bafia', 2),
#   ('director', 2),
#   ('4000', 2),
#   ('manages', 2),
#   ('manager', 2),
#   ('robbani', 2),
#   ('general', 2)],
#  'outstanding loans of dfis rise 105': [('dfis', 8),
#   ('bank', 8),
#   ('loans', 7),
#   ('total', 7),
#   ('credit', 6),
#   ('increased', 6),
#   ('year', 6),
#   ('outstanding', 5),
#   ('bhd', 5),
#   ('respectively', 5),
#   ('malaysia', 5),
#   ('end2003', 4),
#   ('activities', 4),
#   ('lending', 4),
#   ('financing', 4),
#   ('guarantee', 3),
#   ('insurance', 3),
#   ('provided', 3),
#   ('ratio', 2),
#   ('recorded', 2),
#   ('representing', 2),
#   ('rose', 2),
#   ('enterprises', 2),
#   ('government', 2),
#   ('npl', 2),
#   ('gross', 2),
#   ('end', 2),
#   ('bsn', 2),
#   ('deposits', 2),
#   ('pembangunan', 2)],
#  'malaysia to focus on nonbank financial institutions': [('islamic', 12),
#   ('said', 10),
#   ('institutions', 7),
#   ('banking', 6),
#   ('important', 5),
#   ('nbfis', 5),
#   ('financial', 5),
#   ('development', 4),
#   ('mohamed', 4),
#   ('bhd', 4),
#   ('bank', 4),
#   ('focus', 3),
#   ('capital', 3),
#   ('zakat', 3),
#   ('waqf', 3),
#   ('role', 3),
#   ('successful', 3),
#   ('malaysia', 3),
#   ('play', 3),
#   ('parts', 2),
#   ('corporate', 2),
#   ('date', 2),
#   ('market', 2),
#   ('public', 2),
#   ('candidates', 2),
#   ('inheritance', 2),
#   ('management', 2),
#   ('sector', 2),
#   ('closing', 2),
#   ('private', 2)],
#  'banking on nation building': [('bank', 17),
#   ('said', 15),
#   ('rahim', 7),
#   ('projects', 6),
#   ('development', 6),
#   ('infrastructure', 6),
#   ('year', 5),
#   ('financial', 5),
#   ('bhd', 5),
#   ('2002', 4),
#   ('various', 4),
#   ('small', 4),
#   ('bpimb', 3),
#   ('bumiputra', 3),
#   ('lender', 3),
#   ('banks', 3),
#   ('advisory', 3),
#   ('years', 3),
#   ('government', 3),
#   ('continue', 3),
#   ('banking', 3),
#   ('implemented', 2),
#   ('raise', 2),
#   ('technical', 2),
#   ('corporate', 2),
#   ('business', 2),
#   ('quite', 2),
#   ('financing', 2),
#   ('current', 2),
#   ('rates', 2)],
#  '27 growth target for agriculture': [('food', 4),
#   ('new', 3),
#   ('greater', 3),
#   ('development', 3),
#   ('agricultural', 3),
#   ('sector', 3),
#   ('production', 3),
#   ('activities', 3),
#   ('hectares', 2),
#   ('efforts', 2),
#   ('facilities', 2),
#   ('crops', 2),
#   ('irrigation', 2),
#   ('services', 2),
#   ('provide', 2),
#   ('distribution', 2),
#   ('industrial', 2),
#   ('market', 2),
#   ('target', 2),
#   ('commercial', 2),
#   ('adequate', 1),
#   ('improvements', 1),
#   ('mechanisation', 1),
#   ('widespread', 1),
#   ('product', 1),
#   ('sungai', 1),
#   ('improved', 1),
#   ('opportunities', 1),
#   ('business', 1),
#   ('improving', 1)],
#  'greater efforts needed  to boost islamic financing': [('islamic', 22),
#   ('financial', 12),
#   ('debt', 7),
#   ('market', 7),
#   ('said', 6),
#   ('zeti', 5),
#   ('institutions', 5),
#   ('securities', 4),
#   ('instruments', 4),
#   ('development', 4),
#   ('private', 3),
#   ('industry', 3),
#   ('money', 3),
#   ('issues', 2),
#   ('dr', 2),
#   ('akhtar', 2),
#   ('outstanding', 2),
#   ('players', 2),
#   ('place', 2),
#   ('regulatory', 2),
#   ('new', 2),
#   ('banking', 2),
#   ('needs', 2),
#   ('tan', 2),
#   ('capital', 2),
#   ('conventional', 2),
#   ('aziz', 2),
#   ('negara', 2),
#   ('sri', 2),
#   ('operations', 1)],
#  'challenges in fiscal consolidation process': [('fiscal', 4),
#   ('financial', 3),
#   ('package', 3),
#   ('tax', 3),
#   ('budget', 2),
#   ('negara', 2),
#   ('expenditure', 2),
#   ('revenue', 2),
#   ('government', 2),
#   ('offbudget', 2),
#   ('performance', 2),
#   ('agents', 2),
#   ('sources', 2),
#   ('financing', 2),
#   ('year', 2),
#   ('hotel', 2),
#   ('sarsaffected', 2),
#   ('stimulate', 2),
#   ('operators', 2),
#   ('stimulus', 2),
#   ('development', 2),
#   ('rose', 2),
#   ('institutions', 2),
#   ('relief', 2),
#   ('bank', 2),
#   ('growth', 2),
#   ('smes', 2),
#   ('economy', 2),
#   ('balance', 2),
#   ('malaysia', 2)],
#  'bank industri posts record pretax profit': [('bank', 17),
#   ('bhd', 9),
#   ('industri', 9),
#   ('othman', 6),
#   ('said', 6),
#   ('malaysia', 5),
#   ('exim', 5),
#   ('wrp', 3),
#   ('teknologi', 3),
#   ('gmv', 3),
#   ('sri', 3),
#   ('performance', 3),
#   ('tan', 3),
#   ('chairman', 3),
#   ('ann', 2),
#   ('increase', 2),
#   ('md', 2),
#   ('pretax', 2),
#   ('pacific', 2),
#   ('industris', 2),
#   ('kwong', 2),
#   ('recovery', 2),
#   ('bad', 2),
#   ('group', 2),
#   ('result', 2),
#   ('financial', 2),
#   ('debts', 2),
#   ('lew', 2),
#   ('asia', 2),
#   ('profit', 2)],
#  'public bank govt stimulus impact positive': [('said', 8),
#   ('package', 8),
#   ('spending', 7),
#   ('economic', 6),
#   ('fiscal', 6),
#   ('measures', 5),
#   ('economy', 4),
#   ('deficit', 4),
#   ('incentives', 4),
#   ('expected', 3),
#   ('higher', 3),
#   ('domestic', 3),
#   ('business', 3),
#   ('tax', 3),
#   ('income', 3),
#   ('consumer', 3),
#   ('short', 3),
#   ('report', 3),
#   ('source', 2),
#   ('greater', 2),
#   ('direct', 2),
#   ('term', 2),
#   ('small', 2),
#   ('funds', 2),
#   ('long', 2),
#   ('investment', 2),
#   ('increase', 2),
#   ('include', 2),
#   ('smes', 2),
#   ('industries', 2)],
#  'new 3phase 5year plan to transform bsn': [('bsn', 7),
#   ('azim', 6),
#   ('said', 5),
#   ('bank', 3),
#   ('offer', 3),
#   ('financial', 3),
#   ('plan', 3),
#   ('projects', 3),
#   ('institutions', 3),
#   ('business', 2),
#   ('management', 2),
#   ('strategic', 2),
#   ('funds', 2),
#   ('services', 2),
#   ('challenges', 2),
#   ('certain', 2),
#   ('new', 2),
#   ('embarked', 2),
#   ('development', 2),
#   ('government', 2),
#   ('face', 1),
#   ('operate', 1),
#   ('specially', 1),
#   ('applicants', 1),
#   ('nasional', 1),
#   ('invests', 1),
#   ('society', 1),
#   ('percentage', 1),
#   ('worth', 1),
#   ('operations', 1)],
#  'government unveils economic stimulus package': [('player', 9),
#   ('government', 8),
#   ('incentives', 7),
#   ('mahathir', 7),
#   ('dr', 6),
#   ('tax', 6),
#   ('said', 5),
#   ('media', 5),
#   ('package', 5),
#   ('economic', 5),
#   ('real', 5),
#   ('growth', 4),
#   ('funds', 4),
#   ('companies', 4),
#   ('measures', 4),
#   ('foreign', 4),
#   ('stimulus', 4),
#   ('especially', 4),
#   ('people', 3),
#   ('tourism', 3),
#   ('relief', 3),
#   ('investment', 3),
#   ('year', 3),
#   ('smes', 3),
#   ('banks', 3),
#   ('new', 3),
#   ('lot', 2),
#   ('low', 2),
#   ('putrajaya', 2),
#   ('helping', 2)],
#  'benchmark ops fmm tells banks': [('fmm', 7),
#   ('financial', 7),
#   ('smes', 6),
#   ('loan', 4),
#   ('proposed', 4),
#   ('institutions', 4),
#   ('loans', 4),
#   ('cost', 4),
#   ('fis', 3),
#   ('rate', 3),
#   ('said', 3),
#   ('rates', 3),
#   ('documents', 2),
#   ('development', 2),
#   ('plans', 2),
#   ('assets', 2),
#   ('companies', 2),
#   ('business', 2),
#   ('collateral', 2),
#   ('banks', 2),
#   ('alternative', 2),
#   ('15', 2),
#   ('ensure', 2),
#   ('competitive', 2),
#   ('small', 2),
#   ('malaysian', 2),
#   ('guarantees', 2),
#   ('continued', 1),
#   ('expansion', 1),
#   ('facilitate', 1)],
#  'bank negara sets up sme special unit': [('smes', 7),
#   ('financing', 5),
#   ('unit', 5),
#   ('special', 5),
#   ('viable', 3),
#   ('provide', 2),
#   ('sources', 2),
#   ('funds', 2),
#   ('financial', 2),
#   ('bank', 2),
#   ('negara', 2),
#   ('various', 2),
#   ('help', 1),
#   ('address', 1),
#   ('5pm', 1),
#   ('fax', 1),
#   ('facilitate', 1),
#   ('today', 1),
#   ('said', 1),
#   ('securing', 1),
#   ('include', 1),
#   ('contact', 1),
#   ('require', 1),
#   ('process', 1),
#   ('banking', 1),
#   ('continue', 1),
#   ('requirements', 1),
#   ('6954', 1),
#   ('mediumsize', 1),
#   ('faced', 1)],
#  'new measures proactive': [('sector', 9),
#   ('private', 9),
#   ('growth', 6),
#   ('year', 5),
#   ('economic', 4),
#   ('financial', 4),
#   ('economists', 4),
#   ('bank', 4),
#   ('said', 4),
#   ('economist', 3),
#   ('global', 3),
#   ('conditions', 3),
#   ('consumption', 3),
#   ('companies', 3),
#   ('say', 3),
#   ('rate', 3),
#   ('negara', 2),
#   ('lot', 2),
#   ('uncertainties', 2),
#   ('abm', 2),
#   ('funds', 2),
#   ('low', 2),
#   ('spending', 2),
#   ('institutions', 2),
#   ('demand', 2),
#   ('45', 2),
#   ('forecast', 2),
#   ('consumers', 2),
#   ('rates', 2),
#   ('consolidating', 2)],
#  '19 fsmp suggestions implemented by last month': [('financial', 9),
#   ('bank', 5),
#   ('year', 4),
#   ('fsmp', 4),
#   ('institutions', 4),
#   ('core', 4),
#   ('said', 4),
#   ('domestic', 4),
#   ('implemented', 4),
#   ('phase', 4),
#   ('banking', 4),
#   ('iofc', 3),
#   ('emerge', 3),
#   ('labuan', 3),
#   ('islamic', 3),
#   ('negara', 3),
#   ('end', 3),
#   ('recommendations', 3),
#   ('new', 2),
#   ('envisaged', 2),
#   ('market', 2),
#   ('central', 2),
#   ('offshore', 2),
#   ('players', 2),
#   ('gap', 2),
#   ('strong', 2),
#   ('fully', 2),
#   ('banks', 2),
#   ('services', 2),
#   ('foreign', 2)]}

# %%
# Print the top 15 words in each news
for news, top_words in top_dict.items():
    print(news)
    print(', '.join([word for word, count in top_words[0:14]]))
    print('---')
# Out:
# dfis should be assessed beyond financial performance
# dfis, said, role, terms, performance, new, support, mandate, anuar, economy, areas, malaysia, dfi, banks
# ---
# bank pembangunan 2019 pretax profit jumps declares rm152m dividend
# financial, bank, banks, pembangunan, share, income, plan, dividend, net, total, said, higher, performance, institutions
# ---
# as lockdowns ease a bronx nail salon plans a careful reopening
# caraballo, nail, salon, ppp, new, billion, said, help, businesses, ago, half, york, loans, clients
# ---
# us fed says working to broaden access to ppp facility beyond banks
# banks, program, institutions, small, loans, business, financial, fed, paycheck, washington, announce, including, allows, thursday
# ---
# bank negara to ensure sufficient ringgit liquidity
# financial, liquidity, market, bank, said, fiscal, markets, negara, dollar, central, committee, onshore, economic, global
# ---
# providing sme support in times of need
# financing, smes, cgc, facility, sme, pfis, guarantee, moratorium, apply, imsme, financial, visit, srf, bnm
# ---
# bank negara ensures sufficient ringgit liquidity in onshore market
# financial, market, liquidity, said, bank, markets, fiscal, dollar, repo, central, negara, committee, onshore, global
# ---
# why are not all glcs roped in to contribute
# government, minister, bank, package, stimulus, crisis, ecosystem, prime, glcs, economy, people, funds, nexus, need
# ---
# moratorium is automatic says bank negara
# deferment, loanfinancing, repayment, package, credit, banks, period, borrowerscustomers, bank, loansfinancing, card, deferred, continue, outstanding
# ---
# bank negara no need to apply interest will be accrued
# deferment, loanfinancing, repayment, credit, borrowerscustomers, period, banks, loansfinancing, bank, deferred, institutions, outstanding, card, continue
# ---
# bank negara releases faq
# services, period, providers, financial, mco, bank, essential, service, branches, containment, insurance, work, need, epayment
# ---
# essential financial services remain accessible
# services, financial, ensure, providers, bank, public, money, said, service, period, negara, banking, remittance, open
# ---
# reaching out to the smes
# bank, financing, rakyat, cooperatives, malaysia, rosman, bhd, smes, personal, banks, development, banking, said, cooperative
# ---
# pressure mounts on government as economic worries intensify
# growth, fiscal, economy, stimulus, economic, package, bank, governments, deficit, quarter, 2020, 4q19, investment, government
# ---
# dfi merger talks begin
# bank, dfis, financing, merger, sme, bpmb, development, bhd, malaysia, institutions, economy, year, committee, said
# ---
# bank pembangunan danajamin receive bnm approval for merger talks
# bank, merger, bpmb, danajamin, bhd, malaysia, development, said, committee, governments, negara, expected, phase, steering
# ---
# bank rakyat 9m pbtz up 4 to rm129b
# financing, bank, said, groups, islamic, profit, group, profits, rakyat, cir, performance, rate, higher, noripah
# ---
# budget 2020 – a visionary change towards spv2030
# budget, year, 2020, tax, likely, minister, proposals, expected, property, growth, investments, cost, new, given
# ---
# plan to merge 4 dfis can improve efficiencies
# bank, dfis, institutions, development, pembangunan, mandates, bhd, merger, proposal, year, malaysia, said, new, financial
# ---
# industry players and ceos give their views
# digital, scheme, governments, government, growth, smes, budget, economy, financing, group, support, 2020, year, bhd
# ---
# full text of budget 2020 speech
# government, million, malaysia, digital, year, 2020, billion, years, new, tax, development, 2019, economic, allocate
# ---
# budget 2020 four dfis to merge into one entity
# bank, bhd, malaysia, development, dfis, financial, strengthen, entity, exportimport, finance, lumpur, sme, institutions, pembangunan
# ---
# insightful workshop for entrepreneurs
# smes, business, says, bhd, star, resources, trade, lim, soba, relevant, ecosystem, agencies, products, market
# ---
# sme bank targets higher financing
# bank, sme, smes, financing, programme, said, business, digital, transformation, total, aria, role, putera, competition
# ---
# increase in financing for cooperatives depends on bank rakyats capability
# bank, financing, banks, financial, said, rakyat, grew, previously, plan, national, dividend, based, cooperatives, compared
# ---
# ambank bags a double at cgc sme awards
# award, fi, financial, bumiputera, category, awards, commitment, cgc, recognises, providing, fis, credit, partner, bhd
# ---
# time to boost islamic deposits
# islamic, banking, said, growth, badlisyah, industry, banks, deposits, finance, funds, asset, growing, noted, institutional
# ---
# understanding sme financing in malaysia
# financing, smes, bank, business, respondents, financial, firms, says, survey, institutions, insufficient, applications, higher, sources
# ---
# enhancing the role of development financial institutions
# dfis, development, framework, performance, bank, focus, mandates, impact, measurement, finance, necessary, aims, continue, 2018
# ---
# tailormade for women
# smes, women, cgc, said, mohd, financing, malaysia, scheme, chartered, entrepreneurs, standard, financial, tranches, institutions
# ---
# bank negara issues policy paper on outsourcing
# outsourcing, management, policy, senior, financial, board, banks, document, plan, risk, requirements, arrangements, institutions, ability
# ---
# rhb bank bsn bank of china offer lowest lending rates
# bank, base, rate, rhb, bhd, rates, blr, islamic, bhds, bfr, financing, bsn, 685, lending
# ---
# standing tall together
# bhd, chinese, malays, malaysia, population, indians, politicians, police, million, companies, nonmalays, race, government, malaysian
# ---
# strong growth in car loan applications approvals during tax holiday
# cent, said, growth, outstanding, july, bnm, month, august, loan, central, capital, respectively, financial, increased
# ---
# bank negara dfis need to diversify sources of funding
# dfis, development, financial, shamsiah, said, bank, negara, landscape, added, sustainable, support, institutions, mandates, success
# ---
# dfis need to ensure long term financial sustainability
# dfis, said, development, financial, support, sustainable, shamsiah, bnm, contribute, business, application, proportionality, good, health
# ---
# cgc awards financial institutions and customers for participating in schemes
# cgc, bhd, financial, smes, awards, guarantee, sme, bank, said, partner, fi, award, maybank, banking
# ---
# its time to tame the glc monster
# glcs, government, companies, private, firms, economy, ownership, institutions, reforms, politicians, economic, minister, business, listed
# ---
# bank negara says rm33b funds still available for smes
# smes, said, cent, fund, institutions, financial, financing, bank, total, marina, funding, funds, provided, billion
# ---
# mohd zamree wins 2018 outstanding ceo award
# cgc, development, financing, ceo, award, mohd, institutions, financial, 2018, outstanding, sme, smes, respective, credit
# ---
# bank negaras rm500m disaster relief fund for floodhit smes
# bank, financing, financial, said, affected, bnm, facility, bhd, smes, institutions, public, malaysia, flood, available
# ---
# govt debt is moderate says finance ministry
# debt, said, institutions, ministry, domestic, credit, government, bank, act, gdp, consumer, 10, banking, sales
# ---
# smes urged to leverage on bank negara sme fund
# smes, fund, financing, funds, institutions, financial, sme, support, total, banks, allocation, segments, different, development
# ---
# bank negara to issue guidelines on cryptocurrencies
# said, growth, inflation, muhammad, industry, bank, economic, financial, institutions, rate, development, korean, new, bitcoin
# ---
# development financial institutions can be an agent of change says bnm governor
# development, institutions, said, muhammad, financial, sectors, performance, private, korean, key, accountability, corporate, highlighted, increase
# ---
# bnm to issue rules on cryptocurrencies by year end
# said, economic, guidelines, ringgit, muhammad, important, want, end, reflect, malaysia, strength, year, bnm, local
# ---
# net financing to private sector grew 54 in february
# net, loans, capital, growth, banking, ratio, loan, january, pace, grew, expansion, february, 54, level
# ---
# highlights of bank negara financial stability report 2016
# growth, financial, financing, sector, debt, islamic, banking, payment, banks, 2016, motor, insurance, development, bank
# ---
# malaysias economy records 45 growth in q4 of 2016
# growth, said, 2016, bnm, financial, sector, services, domestic, quarter, private, manufacturing, 3q, higher, continued
# ---
# broad money grows a steady 3 in december
# growth, loans, banking, expansion, november, net, driven, outstanding, december, annual, loan, households, slightly, amid
# ---
# banking systems outstanding business loans up 5 in december
# growth, december, november, loans, net, recorded, outstanding, said, banking, month, slightly, business, annual, sectors
# ---
# bank negara issues draft on credit risk management
# risk, bank, requirements, credit, management, financial, central, proposals, institutions, key, regulatory, draft, effective, written
# ---
# broad money growth falls in november
# growth, october, loans, outstanding, net, november, banking, driven, higher, continued, expansion, annual, month, loan
# ---
# fuming over unjust fees
# financial, pay, services, charge, fee, bank, psc, consumers, ofs, banks, disputes, charges, paying, card
# ---
# ombudsman for financial services starts oct 1
# financial, ombudsman, services, disputes, consumers, said, scheme, payment, bnm, takaful, insurance, act, independent, court
# ---
# cooperative bank for personal financing
# bank, rakyat, bhd, malaysia, financial, cooperative, key, personal, falls, set, negara, simpanan, institutions, civil
# ---
# m3 grows 23 in july says bank negara
# month, said, bnm, july, net, growth, continued, ratio, banking, capital, average, equity, ringgit, private
# ---
# auditors find it tough to unmask corporate fraud
# fraud, corporate, says, companies, malaysia, heng, report, bhd, 1mdb, say, financial, people, years, year
# ---
# broad money growth at 19 in june says bnm
# loans, growth, loan, ratio, banking, capital, continued, said, money, net, month, households, tier, lower
# ---
# cgc targets rm145bil sme loan base by 2020
# smes, sme, financing, year, rate, base, mohd, firm, plan, partner, cgcs, awards, f1, islamic
# ---
# alternative financing beckons
# smes, business, vcs, funds, alternative, said, businesses, investors, small, companies, foo, development, proposal, looking
# ---
# malaysia is weathering the economic storm with bold measures
# government, tax, cut, expenditure, revenue, measures, economy, oil, did, fiscal, public, benefit, gst, budget
# ---
# briefs
# said, government, companies, chapter, malaysia, smes, ecommerce, tppa, growth, chan, procurement, funding, online, policies
# ---
# dealing with hard times
# budget, economic, 2016, growth, oil, government, measures, year, prices, crude, barrel, spending, new, recalibrated
# ---
# welcome news for smes and startups
# smes, capital, venture, said, economic, prime, funds, business, startups, wee, enterprises, rm6bil, announcement, government
# ---
# budget 2016 revision several key measures to be taken
# increase, government, including, development, reduce, benefit, budget, 2016, month, management, workers, income, contributions, foreign
# ---
# budget 2016 revision full text of pms speech
# government, economic, 2016, economy, rakyat, budget, measure, measures, global, billion, programme, domestic, prices, oil
# ---
# najib presents revised 2016 budget
# budget, said, government, 2016, najib, economic, global, measures, increase, benefit, growth, capital, including, price
# ---
# cgc to develop credit guarantee framework for smes in rwanda
# cgc, bdf, development, rwanda, countries, guarantee, said, credit, smes, sme, mohd, share, zamree, visits
# ---
# bank negara enhances consumer protection in disputes involving banks and insurers
# fos, financial, services, ombudsman, resolution, consumers, islamic, fsps, banks, approved, disputes, scheme, review, bank
# ---
# access for smes to bnms special funds channel
# smes, funds, financing, bhd, bnm, bank, development, small, medium, said, malaysia, institutions, financial, years
# ---
# govt denies us150mil loan given to 1mdb was to purchase land in pulau indah
# loan, bank, exim, 1mdbs, 1mdb, support, government, overseas, said, import, power, deputy, given, mandate
# ---
# breaking down barriers to financing
# said, entrepreneurs, business, bankers, teoh, smes, forum, loan, bank, koong, banks, cedar, entrepreneur, development
# ---
# china japan finance ministers concerned about volatile commodity prices
# finance, global, economy, volatile, prices, beijing, concerns, infrastructure, said, development, minister, sides, economic, commodity
# ---
# boost for chinese smes
# loans, smes, said, businesses, loan, financial, wee, kojadi, working, years, fund, applicants, banks, asking
# ---
# smebiz briefs
# banks, sme, islamic, development, finance, bank, smes, banker, said, business, companies, malaysia, prices, financial
# ---
# plenty of funding for smes cgc
# smes, financial, financing, loans, cgc, institutions, small, kong, products, hong, available, hon, businesses, malaysia
# ---
# rm32bil remitted by foreign workers last year
# money, said, country, licensed, act, services, chua, datuk, remit, question, financial, changers, institutions, total
# ---
# bank negara completes public consultation on dfi
# consultation, requirements, dfi, criteria, bank, development, management, negara, business, dfia, proper, feedback, financial, public
# ---
# bnm completes public consultation on dfi management criteria
# requirements, bank, feedback, dfia, proper, criteria, development, consultation, institutions, financial, bnm, dfi, central, business
# ---
# rm893mil to be set aside under budget 2015 for flood mitigation projects
# government, loan, months, said, najib, financial, development, floods, flood, areas, recent, financing, special, added
# ---
# budget revision full text of prime ministers speech
# oil, government, 2015, prices, crude, economic, budget, measures, fiscal, services, malaysia, gdp, global, billion
# ---
# husni urges multilateral organisations to consolidate their expertise resources
# said, infrastructure, bank, investments, apec, finance, husni, enhance, initiatives, development, economic, aif, investment, private
# ---
# bank negara seeks publics feedback on amending financial act
# bank, dfis, development, financial, malaysia, bhd, institutions, feedback, ensure, draft, strategic, dfia, said, added
# ---
# economic report 201415 us policy will still hold sway
# financial, 2014, banking, sector, sukuk, loans, continued, total, july, global, markets, smes, loan, activities
# ---
# economic report 201415 household loan approvals continue to grow
# household, financial, loans, 2014, households, assets, total, debt, remained, loan, disbursed, accounted, banking, continued
# ---
# financial services five critical targets
# financial, platform, new, said, nkea, framework, year, report, national, exchange, industrys, finance, asean, target
# ---
# comfortable household debt level
# household, debt, measures, said, banks, malaysia, added, rising, banking, current, housing, sector, new, increase
# ---
# economic report 20132014 banking system capital market stronger
# market, 2013, malaysia, sukuk, total, outstanding, financial, islamic, act, legal, banking, capital, support, nasional
# ---
# rm42bil govt housing loan transfer should boost lenders
# loans, growth, housing, banks, loan, government, commercial, banking, said, 2013, transfer, bank, financial, july
# ---
# spectre of rising household debt
# measures, household, debt, said, property, personal, financing, latest, loans, curb, include, speculative, activities, bank
# ---
# mbsb under spotlight
# mbsb, bank, financial, loans, banking, says, negara, mbsbs, fsa, quarter, fy12, march, stability, deemed
# ---
# agrobank aims to trim npl to single digit by yearend
# said, development, bank, service, stringent, prudent, wan, npl, institutions, banking, banks, datuk, management, ensure
# ---
# mbsb no plan for dfi status
# said, personal, mbsb, clifford, financing, year, financial, dfi, launched, processes, preparing, products, internally, apply
# ---
# smes in palm oil urged to venture into refined downstream activities
# oil, palm, smes, says, sme, activities, programme, small, downstream, financing, karunajothi, companies, sector, total
# ---
# a time for professional scepticism
# concern, going, aob, audit, financial, uhy, assumption, 2010, board, standards, area, management, auditing, reprimand
# ---
# auditor penalised for failure to meet standards
# audit, aob, financial, firms, reprimand, pies, uhy, sc, auditors, tee, hasyudeen, companies, malaysia, issued
# ---
# financial sector urged to be more attentive to environmental issues
# institutions, financial, environmental, environment, finance, development, adfiap, wan, issues, standards, banking, research, deplete, climate
# ---
# shadow banks on bank negaras radar screen
# lending, nonbank, bank, credit, financial, activities, institutions, banking, banks, said, negara, growth, intermediated, financing
# ---
# nonbank lenders unperturbed by responsible lending guidelines
# guidelines, mbsb, financing, growth, loan, said, lending, year, financial, civil, new, credit, government, servants
# ---
# marc limit lending by nonbanks to contain household debt
# household, bank, sector, lending, financial, credit, debt, said, rating, central, growth, banking, 2011, gdp
# ---
# household debt rise a concern
# growth, household, loan, income, debt, said, year, strong, financing, ratio, banking, banks, gross, capital
# ---
# bank negara unveils new financing rules
# guidelines, financing, responsible, banks, lending, said, financial, loans, borrowers, practices, ensure, credit, bank, cooperatives
# ---
# aob flexes regulatory muscles
# firms, audit, registration, aob, auditors, partners, inspections, board, period, horwath, individual, companies, year, said
# ---
# level of personal loans not a worry
# personal, financing, household, customers, said, growth, financial, loan, loans, debt, rise, year, banks, risk
# ---
# drbhicom keen on merger between bank muamalat and bimb
# bank, islamic, said, bhd, muamalat, merger, malaysia, drbhicom, development, exploring, bimb, possible, finance, growth
# ---
# banking consolidation third round
# banks, banking, bank, investment, says, market, financial, consolidation, rhb, stake, capital, foreign, need, business
# ---
# reliable audit opinions dont come cheap
# audit, fees, firms, auditors, aob, work, board, services, malaysia, report, companies, clients, annual, standards
# ---
# big four among audit firms with faults
# audit, firms, work, board, inspections, areas, said, mohd, aob, report, annual, hasyudeen, evidence, nik
# ---
# managing household debt
# credit, household, financial, debt, card, says, financing, bank, cards, banks, institutions, negara, borrowers, new
# ---
# enhancing the contribution of islamic finance
# islamic, finance, takaful, assets, malaysias, family, licences, negara, new, global, development, financial, bank, sector
# ---
# demand rebound lifts residential property market
# credit, household, financing, increased, personal, 2010, ratio, house, borrowers, balances, card, number, cards, including
# ---
# outstanding banking system financing up 127
# financing, support, companies, fund, total, development, funds, green, creative, 2010, assistance, outstanding, technology, market
# ---
# five audit firms run afoul of board
# auditors, firms, aob, companies, registered, registration, april, register, pies, board, act, hasyudeen, law, day
# ---
# proposal for epf members to invest in private pension funds
# epf, services, financial, funds, management, market, pension, development, assets, retail, income, private, proposed, companies
# ---
# sme credit bureau to launch countrys first credit monitoring services for smes
# credit, smes, information, bureau, sme, financial, institutions, data, cms, changes, rating, banks, says, time
# ---
# warren buffett goldman sachs in us500mil assistance drive
# business, small, goldman, community, businesses, sachs, financial, development, new, buffett, america, million, owners, said
# ---
# plan for investor dispute mediation
# capital, investors, market, financial, disputes, said, resolution, sc, dispute, industry, payment, mechanism, banks, fmb
# ---
# bright outlook for micro credit say banks
# micro, bank, finance, year, credit, said, loans, low, scheme, enterprises, demand, tay, banks, loan
# ---
# a robust system in place
# financial, institutions, bank, central, market, development, comprehensive, institutional, regulatory, past, restructuring, building, framework, sector
# ---
# deposit insurer aims for greater awareness
# deposit, insurance, bank, public, pidm, loganathan, deposits, financial, awareness, member, malaysia, banks, risk, premium
# ---
# npls kept in check
# business, says, bank, smes, credit, sme, group, banking, financial, npl, current, npls, management, malaysia
# ---
# return to deposit insurance limit on the cards
# guarantee, pidm, malaysia, deposit, government, blanket, banks, said, insurance, rm60000, year, islamic, guaranteed, place
# ---
# precautionary moves put households on stronger ground
# financial, households, continued, bank, income, household, ratio, servicing, years, performance, negara, statements, debt, economic
# ---
# private sector benefits from financing flexibility
# financing, business, sector, banking, bank, total, loans, negara, click, finance, remained, insurance, primarily, gross
# ---
# smes get loans after bank negara intervenes
# smes, banks, bank, loan, loans, says, customers, business, financial, sme, credit, year, rate, association
# ---
# companies finding it difficult to get bank loans
# banks, lending, bank, said, loans, smes, lim, approved, latest, reduced, business, ensure, including, enterprises
# ---
# abdullah carry on backing smes
# smes, said, sector, economic, development, government, support, sme, private, extended, continue, institutions, banking, country
# ---
# govt fully guarantees deposits via pidm
# financial, said, malaysian, strong, institutions, bank, measures, negara, government, guarantee, regulated, extended, fully, depositors
# ---
# banks upbeat on microfinancing
# microfinance, micro, said, enterprises, small, growth, financial, banks, bank, financing, tay, institutions, loan, year
# ---
# better funding access for smes
# financing, institutions, sme, 2007, smes, banking, dfis, approved, report, financial, negara, annual, increased, access
# ---
# financing key to growth of smes
# smes, loans, institutions, banking, financing, sme, total, 2006, payments, business, financial, working, collections, accounts
# ---
# islamic banking a vibrant alternative system
# islamic, financial, takaful, business, development, assets, tax, foreign, international, banking, mifc, malaysia, centre, treatment
# ---
# cgc targets smes for its latest credit guarantee scheme
# guarantee, cgc, smes, credit, business, scheme, new, guaranteed, collateral, islamic, provides, financing, wan, profiles
# ---
# rabobank keen on malaysia ops
# bank, rabobank, malaysia, indonesia, said, operations, banking, source, development, food, industry, acquisitions, china, year
# ---
# smes contribution to gdp on the rise
# sme, smes, report, government, said, expected, fund, development, bank, sector, halal, loans, total, entrepreneurs
# ---
# review and finetune strategies pm tells smes
# said, development, smes, sme, abdullah, financial, government, total, bank, national, provided, financing, products, access
# ---
# loan sharks feel the bite
# bank, loans, businesses, scheme, small, need, negara, collateral, said, public, ah, institutions, enterprises, good
# ---
# stronger prudential and legal framework for banks
# financial, framework, institutions, focus, measures, bank, policy, negara, greater, risk, players, continue, malaysia, initiatives
# ---
# credit guarantee projects higher target this year
# islamic, bhd, bank, cgc, said, banks, year, azhar, loans, guarantee, wan, foreign, growth, partnership
# ---
# cgc expects to guarantee more loans this year
# bhd, islamic, bank, cgc, year, said, banks, loans, wan, guarantee, azhar, credit, growth, partnership
# ---
# council sets aside rm37b for smes
# sme, smes, financial, council, development, programmes, institutions, financing, abdullah, products, marketing, services, year, medium
# ---
# exim bank starts overseas guarantee fund
# bank, said, overseas, kamal, fund, eogf, executive, rhb, negara, cimb, officer, guarantee, mohd, director
# ---
# exim bank  starts overseas guarantee fund
# bank, said, overseas, fund, eogf, kamal, help, companies, malaysian, institutions, financing, capital, banks, guarantee
# ---
# exim bank to gain from merger
# year, bank, said, kamal, new, banks, exim, profit, facility, net, east, confident, financial, 31
# ---
# bank ma rules eased
# bank, said, act, financial, negara, banking, talks, banks, ruling, bhd, institutions, competition, simultaneously, shareholders
# ---
# foreign currency denominated bonds allowed in malaysia
# financial, malaysia, centre, mifc, foreign, islamic, banks, development, negara, bank, market, issuers, dialogue, bonds
# ---
# razif is deputy governor of bank negara
# bank, razif, datuk, negara, islamic, governor, abdul, finance, deputy, financial, central, mohd, development, tenure
# ---
# cgc eyes rm4b loan portfolio
# loans, wan, azhar, said, banks, portfolio, year, sme, cgc, smes, institutions, financial, award, bhd
# ---
# good showing by development financial institutions
# loans, dfis, total, bank, outstanding, extended, credit, higher, sectors, negara, growth, strong, 2004, financing
# ---
# bpimb pretax profit up 19 to rm381mil
# loans, total, 2003, approved, year, industry, 12, loan, increase, net, smes, rose, strong, rm16bil
# ---
# financial system rich in assets
# financial, assets, banks, total, share, 2004, year, insurance, institutions, grew, securities, loans, commercial, advances
# ---
# development financing activities stepped up
# bank, total, loans, bhd, malaysia, outstanding, financing, dfis, infrastructure, sector, sectors, credit, growth, respectively
# ---
# basic banking services at minimal cost from february
# said, financial, fmb, institutions, banking, zeti, services, insurance, bank, consumers, consumer, bureau, negara, sri
# ---
# tax refund procedure made easier
# tax, duty, increase, budget, building, refund, fund, excise, act, allowance, 2005, finance, used, construction
# ---
# reshaping bank industri
# bank, industri, capital, says, banks, othman, bhd, rwcr, time, industries, ratio, malaysia, lending, banking
# ---
# meps in atm tieup with artajasa
# meps, bank, rakyat, atm, datuk, said, alim, atms, services, network, cardholders, artajasa, electronic, mohd
# ---
# outstanding loans of dfis rise 105
# dfis, bank, loans, total, credit, increased, year, outstanding, bhd, respectively, malaysia, end2003, activities, lending
# ---
# malaysia to focus on nonbank financial institutions
# islamic, said, institutions, banking, important, nbfis, financial, development, mohamed, bhd, bank, focus, capital, zakat
# ---
# banking on nation building
# bank, said, rahim, projects, development, infrastructure, year, financial, bhd, 2002, various, small, bpimb, bumiputra
# ---
# 27 growth target for agriculture
# food, new, greater, development, agricultural, sector, production, activities, hectares, efforts, facilities, crops, irrigation, services
# ---
# greater efforts needed  to boost islamic financing
# islamic, financial, debt, market, said, zeti, institutions, securities, instruments, development, private, industry, money, issues
# ---
# challenges in fiscal consolidation process
# fiscal, financial, package, tax, budget, negara, expenditure, revenue, government, offbudget, performance, agents, sources, financing
# ---
# bank industri posts record pretax profit
# bank, bhd, industri, othman, said, malaysia, exim, wrp, teknologi, gmv, sri, performance, tan, chairman
# ---
# public bank govt stimulus impact positive
# said, package, spending, economic, fiscal, measures, economy, deficit, incentives, expected, higher, domestic, business, tax
# ---
# new 3phase 5year plan to transform bsn
# bsn, azim, said, bank, offer, financial, plan, projects, institutions, business, management, strategic, funds, services
# ---
# government unveils economic stimulus package
# player, government, incentives, mahathir, dr, tax, said, media, package, economic, real, growth, funds, companies
# ---
# benchmark ops fmm tells banks
# fmm, financial, smes, loan, proposed, institutions, loans, cost, fis, rate, said, rates, documents, development
# ---
# bank negara sets up sme special unit
# smes, financing, unit, special, viable, provide, sources, funds, financial, bank, negara, various, help, address
# ---
# new measures proactive
# sector, private, growth, year, economic, financial, economists, bank, said, economist, global, conditions, consumption, companies
# ---
# 19 fsmp suggestions implemented by last month
# financial, bank, year, fsmp, institutions, core, said, domestic, implemented, phase, banking, iofc, emerge, labuan
# ---

# %% [markdown]
# **NOTE:** At this point, we could go on and create word clouds. However, by looking at these top words, you can see that some of them have very little meaning and could be added to a stop words list, so let's do just that.

# %%
# Look at the most common top words --> add them to the stop word list
from collections import Counter

# Let's first pull out the top 30 words for each comedian
words = []
for news in data.columns:
    top = [word for (word, count) in top_dict[news]]
    for t in top:
        words.append(t)
        
words
# Out:
# ['dfis',
#  'said',
#  'role',
#  'terms',
#  'performance',
#  'new',
#  'support',
#  'mandate',
#  'anuar',
#  'economy',
#  'areas',
#  'malaysia',
#  'dfi',
#  'banks',
#  'bank',
#  'financial',
#  'government',
#  'noted',
#  'set',
#  'growth',
#  'khairil',
#  'crisis',
#  'sme',
#  'mandated',
#  'smes',
#  'development',
#  'deliverables',
#  'different',
#  'play',
#  'looking',
#  'financial',
#  'bank',
#  'banks',
#  'pembangunan',
#  'share',
#  'income',
#  'plan',
#  'dividend',
#  'net',
#  'total',
#  'said',
#  'higher',
#  'performance',
#  'institutions',
#  'notes',
#  'fy19',
#  'allowance',
#  'lumpur',
#  'lowest',
#  'lower',
#  'reduced',
#  'rm380mil',
#  'executing',
#  'gains',
#  'notably',
#  'redeemable',
#  'fy2019',
#  'remains',
#  'rm25bil',
#  'special',
#  'caraballo',
#  'nail',
#  'salon',
#  'ppp',
#  'new',
#  'billion',
#  'said',
#  'help',
#  'businesses',
#  'ago',
#  'half',
#  'york',
#  'loans',
#  'clients',
#  'month',
#  'rent',
#  'small',
#  'estimates',
#  'know',
#  'business',
#  'funds',
#  'usual',
#  'nearly',
#  'applied',
#  'years',
#  'customers',
#  'government',
#  'technicians',
#  'cleaning',
#  'minority',
#  'banks',
#  'program',
#  'institutions',
#  'small',
#  'loans',
#  'business',
#  'financial',
#  'fed',
#  'paycheck',
#  'washington',
#  'announce',
#  'including',
#  'allows',
#  'thursday',
#  'borrow',
#  'rules',
#  'shortly',
#  'ppp',
#  'broader',
#  'deposittaking',
#  'federal',
#  'use',
#  'array',
#  'reserve',
#  'lending',
#  'administrations',
#  'said',
#  'currently',
#  'expand',
#  'new',
#  'financial',
#  'liquidity',
#  'market',
#  'bank',
#  'said',
#  'fiscal',
#  'markets',
#  'negara',
#  'dollar',
#  'central',
#  'committee',
#  'onshore',
#  'economic',
#  'global',
#  'repo',
#  'commitment',
#  'continue',
#  'activities',
#  'sufficient',
#  'acknowledged',
#  'participants',
#  'including',
#  'discussed',
#  'agreements',
#  'increase',
#  'ensure',
#  'preemptively',
#  'government',
#  'ringgit',
#  'recent',
#  'financing',
#  'smes',
#  'cgc',
#  'facility',
#  'sme',
#  'pfis',
#  'guarantee',
#  'moratorium',
#  'apply',
#  'imsme',
#  'financial',
#  'visit',
#  'srf',
#  'bnm',
#  'contact',
#  'bizmulai',
#  'existing',
#  'imsmecommy',
#  'bizwanitai',
#  'annum',
#  'years',
#  'institutions',
#  'economic',
#  'customers',
#  'business',
#  'sixmonth',
#  'supporting',
#  'schemes',
#  'ongoing',
#  'banks',
#  'financial',
#  'market',
#  'liquidity',
#  'said',
#  'bank',
#  'markets',
#  'fiscal',
#  'dollar',
#  'repo',
#  'central',
#  'negara',
#  'committee',
#  'onshore',
#  'global',
#  'economic',
#  'sufficient',
#  'activities',
#  'participants',
#  'commitment',
#  'continue',
#  'acknowledged',
#  'including',
#  'stimulus',
#  'ensure',
#  'banks',
#  'agreements',
#  'preemptively',
#  'funding',
#  'discussed',
#  'conditions',
#  'government',
#  'minister',
#  'bank',
#  'package',
#  'stimulus',
#  'crisis',
#  'ecosystem',
#  'prime',
#  'glcs',
#  'economy',
#  'people',
#  'funds',
#  'nexus',
#  'need',
#  'muhyiddin',
#  'power',
#  'powerful',
#  'institutions',
#  'help',
#  'firms',
#  'political',
#  'sme',
#  'major',
#  'perikatan',
#  'offer',
#  'support',
#  'mara',
#  'epf',
#  'politicalbusiness',
#  'nasional',
#  'deferment',
#  'loanfinancing',
#  'repayment',
#  'package',
#  'credit',
#  'banks',
#  'period',
#  'borrowerscustomers',
#  'bank',
#  'loansfinancing',
#  'card',
#  'deferred',
#  'continue',
#  'outstanding',
#  'repayments',
#  'meet',
#  'qualify',
#  'institutions',
#  'monthly',
#  'term',
#  'yes',
#  'financial',
#  'months',
#  'financing',
#  'loans',
#  'loan',
#  'need',
#  'criteria',
#  'april',
#  'automatically',
#  'deferment',
#  'loanfinancing',
#  'repayment',
#  'credit',
#  'borrowerscustomers',
#  'period',
#  'banks',
#  'loansfinancing',
#  'bank',
#  'deferred',
#  'institutions',
#  'outstanding',
#  'card',
#  'continue',
#  'package',
#  'repayments',
#  'qualify',
#  'meet',
#  'monthly',
#  'term',
#  'financial',
#  'financing',
#  'months',
#  'loan',
#  'criteria',
#  'need',
#  'individuals',
#  'accrue',
#  'wish',
#  'april',
#  'services',
#  'period',
#  'providers',
#  'financial',
#  'mco',
#  'bank',
#  'essential',
#  'service',
#  'branches',
#  'containment',
#  'insurance',
#  'work',
#  'need',
#  'epayment',
#  'open',
#  'banks',
#  'banking',
#  'operating',
#  'atms',
#  'online',
#  'check',
#  'cash',
#  'terminals',
#  'access',
#  'money',
#  'counter',
#  'refer',
#  'remittance',
#  'operations',
#  'yes',
#  'services',
#  'financial',
#  'ensure',
#  'providers',
#  'bank',
#  'public',
#  'money',
#  'said',
#  'service',
#  'period',
#  'negara',
#  'banking',
#  'remittance',
#  'open',
#  'containment',
#  'continue',
#  'members',
#  'remain',
#  'central',
#  'advised',
#  'uninterrupted',
#  'refer',
#  'branches',
#  'essential',
#  'customers',
#  'institutions',
#  'insurance',
#  'online',
#  'operators',
#  'end',
#  'bank',
#  'financing',
#  'rakyat',
#  'cooperatives',
#  'malaysia',
#  'rosman',
#  'bhd',
#  'smes',
#  'personal',
#  'banks',
#  'development',
#  'banking',
#  'said',
#  'cooperative',
#  'dfis',
#  'grow',
#  'portfolio',
#  'small',
#  'looking',
#  'account',
#  '2018',
#  'financial',
#  'sme',
#  'plan',
#  'medium',
#  'home',
#  'sector',
#  'coming',
#  'government',
#  'islamic',
#  'growth',
#  'fiscal',
#  'economy',
#  'stimulus',
#  'economic',
#  'package',
#  'bank',
#  'governments',
#  'deficit',
#  'quarter',
#  '2020',
#  '4q19',
#  'investment',
#  'government',
#  'says',
#  'expects',
#  'private',
#  'rate',
#  'rating',
#  'domestic',
#  'outbreak',
#  'commodity',
#  '3q19',
#  'market',
#  'yoy',
#  'economist',
#  '1q20',
#  'continue',
#  'supply',
#  'manokaran',
#  'bank',
#  'dfis',
#  'financing',
#  'merger',
#  'sme',
#  'bpmb',
#  'development',
#  'bhd',
#  'malaysia',
#  'institutions',
#  'economy',
#  'year',
#  'committee',
#  'said',
#  'danajamin',
#  'provide',
#  'ministry',
#  'business',
#  'businesses',
#  'expected',
#  'needs',
#  'analyst',
#  'financial',
#  'banking',
#  'mandates',
#  'phase',
#  'restructuring',
#  'new',
#  'added',
#  'proposal',
#  'bank',
#  'merger',
#  'bpmb',
#  'danajamin',
#  'bhd',
#  'malaysia',
#  'development',
#  'said',
#  'committee',
#  'governments',
#  'negara',
#  'expected',
#  'phase',
#  'steering',
#  'working',
#  'comittee',
#  'achieve',
#  'commence',
#  'needs',
#  'bpmbphase',
#  'greater',
#  'support',
#  'budget',
#  'negotiations',
#  'corp',
#  'various',
#  'comprising',
#  'entitythere',
#  'given',
#  'green',
#  'financing',
#  'bank',
#  'said',
#  'groups',
#  'islamic',
#  'profit',
#  'group',
#  'profits',
#  'rakyat',
#  'cir',
#  'performance',
#  'rate',
#  'higher',
#  'noripah',
#  'activities',
#  'largest',
#  'asset',
#  'cost',
#  'pbtz',
#  'encouraging',
#  'sustainable',
#  'institution',
#  'development',
#  'contributed',
#  'treasury',
#  'banking',
#  'nations',
#  'affected',
#  '20',
#  'friday',
#  'budget',
#  'year',
#  '2020',
#  'tax',
#  'likely',
#  'minister',
#  'proposals',
#  'expected',
#  'property',
#  'growth',
#  'investments',
#  'cost',
#  'new',
#  'given',
#  'base',
#  'khazanah',
#  'income',
#  'reduction',
#  'investment',
#  'high',
#  'governments',
#  'sector',
#  'market',
#  'surprise',
#  'time',
#  'toll',
#  'far',
#  'economic',
#  'solar',
#  'spur',
#  'bank',
#  'dfis',
#  'institutions',
#  'development',
#  'pembangunan',
#  'mandates',
#  'bhd',
#  'merger',
#  'proposal',
#  'year',
#  'malaysia',
#  'said',
#  'new',
#  'financial',
#  'performance',
#  'entity',
#  'operations',
#  'financing',
#  'sme',
#  'develop',
#  'finance',
#  'needs',
#  'focus',
#  'turn',
#  'strengthen',
#  'synergies',
#  'indicators',
#  'economy',
#  'negara',
#  'greater',
#  'digital',
#  'scheme',
#  'governments',
#  'government',
#  'growth',
#  'smes',
#  'budget',
#  'economy',
#  'financing',
#  'group',
#  'support',
#  '2020',
#  'year',
#  'bhd',
#  'measures',
#  'ltat',
#  'tax',
#  'boost',
#  'incentives',
#  'economic',
#  'datuk',
#  'ceo',
#  'welcome',
#  'technology',
#  'adoption',
#  'help',
#  'investment',
#  'increase',
#  'housing',
#  'development',
#  'government',
#  'million',
#  'malaysia',
#  'digital',
#  'year',
#  '2020',
#  'billion',
#  'years',
#  'new',
#  'tax',
#  'development',
#  '2019',
#  'economic',
#  'allocate',
#  'second',
#  'growth',
#  'companies',
#  'sri',
#  'income',
#  'malaysian',
#  'malaysians',
#  'speaker',
#  'fund',
#  'sir',
#  'support',
#  'provide',
#  'tan',
#  'smes',
#  'given',
#  'economy',
#  'bank',
#  'bhd',
#  'malaysia',
#  'development',
#  'dfis',
#  'financial',
#  'strengthen',
#  'entity',
#  'exportimport',
#  'finance',
#  'lumpur',
#  'sme',
#  'institutions',
#  'pembangunan',
#  'exim',
#  'restructuring',
#  'enterprise',
#  'negara',
#  'kuala',
#  'small',
#  'danajamin',
#  'nasional',
#  'single',
#  'plan',
#  'berhad',
#  'proposed',
#  'twostage',
#  'medium',
#  'ecosystem',
#  'merge',
#  'smes',
#  'business',
#  'says',
#  'bhd',
#  'star',
#  'resources',
#  'trade',
#  'lim',
#  'soba',
#  'relevant',
#  'ecosystem',
#  'agencies',
#  'products',
#  'market',
#  'eye',
#  'malaysia',
#  'growth',
#  'development',
#  'officer',
#  'chief',
#  'sdn',
#  'group',
#  'customers',
#  'senhengs',
#  'teh',
#  'learning',
#  'key',
#  'years',
#  'addaem',
#  '2019',
#  'bank',
#  'sme',
#  'smes',
#  'financing',
#  'programme',
#  'said',
#  'business',
#  'digital',
#  'transformation',
#  'total',
#  'aria',
#  'role',
#  'putera',
#  'competition',
#  'assist',
#  'entrepreneurs',
#  'targeted',
#  'various',
#  'year',
#  'malaysia',
#  'higher',
#  'development',
#  '2018',
#  'banks',
#  'sales',
#  'conducted',
#  'financial',
#  'export',
#  'participants',
#  'cedar',
#  'bank',
#  'financing',
#  'banks',
#  'financial',
#  'said',
#  'rakyat',
#  'grew',
#  'previously',
#  'plan',
#  'national',
#  'dividend',
#  'based',
#  'cooperatives',
#  'compared',
#  'development',
#  'datuk',
#  'report',
#  'board',
#  'fy18',
#  'directors',
#  '13',
#  'noripah',
#  'efforts',
#  'business',
#  'increase',
#  'especially',
#  'home',
#  'rakyats',
#  'amounting',
#  'balance',
#  'award',
#  'fi',
#  'financial',
#  'bumiputera',
#  'category',
#  'awards',
#  'commitment',
#  'cgc',
#  'recognises',
#  'providing',
#  'fis',
#  'credit',
#  'partner',
#  'bhd',
#  'guarantee',
#  'financing',
#  'smes',
#  'appreciation',
#  'recent',
#  'receive',
#  'support',
#  'lumpur',
#  'relevant',
#  'ambank',
#  'needs',
#  'corporation',
#  'datuk',
#  'institution',
#  'executive',
#  'testament',
#  'islamic',
#  'banking',
#  'said',
#  'growth',
#  'badlisyah',
#  'industry',
#  'banks',
#  'deposits',
#  'finance',
#  'funds',
#  'asset',
#  'growing',
#  'noted',
#  'institutional',
#  'financing',
#  'conventional',
#  'attract',
#  'needs',
#  'term',
#  'vbi',
#  'ciif',
#  'size',
#  'professionals',
#  'long',
#  'intermediation',
#  'professional',
#  '11',
#  'expected',
#  'body',
#  'total',
#  'financing',
#  'smes',
#  'bank',
#  'business',
#  'respondents',
#  'financial',
#  'firms',
#  'says',
#  'survey',
#  'institutions',
#  'insufficient',
#  'applications',
#  'higher',
#  'sources',
#  'mainly',
#  '22',
#  'cash',
#  'applied',
#  'costs',
#  'central',
#  'negara',
#  'documentation',
#  'services',
#  'rejection',
#  '2018',
#  'products',
#  'main',
#  'reported',
#  'average',
#  'funds',
#  'dfis',
#  'development',
#  'framework',
#  'performance',
#  'bank',
#  'focus',
#  'mandates',
#  'impact',
#  'measurement',
#  'finance',
#  'necessary',
#  'aims',
#  'continue',
#  '2018',
#  'world',
#  'institutions',
#  'effectively',
#  'key',
#  'growth',
#  'financing',
#  'enhanced',
#  'central',
#  'financial',
#  'new',
#  'indicators',
#  'petaling',
#  'measure',
#  'optimising',
#  'malaysia',
#  'supervisory',
#  'smes',
#  'women',
#  'cgc',
#  'said',
#  'mohd',
#  'financing',
#  'malaysia',
#  'scheme',
#  'chartered',
#  'entrepreneurs',
#  'standard',
#  'financial',
#  'tranches',
#  'institutions',
#  'pg',
#  'guarantee',
#  'chief',
#  'officer',
#  'scm',
#  'zamree',
#  'abrar',
#  'collaboration',
#  'amiruddin',
#  'saadiq',
#  'anniversary',
#  'finance',
#  'development',
#  'economy',
#  'need',
#  'inclusion',
#  'outsourcing',
#  'management',
#  'policy',
#  'senior',
#  'financial',
#  'board',
#  'banks',
#  'document',
#  'plan',
#  'risk',
#  'requirements',
#  'arrangements',
#  'institutions',
#  'ability',
#  'bank',
#  'service',
#  'obtain',
#  'statement',
#  'governance',
#  'customers',
#  'oversight',
#  'feedback',
#  'ensure',
#  'issued',
#  'negara',
#  'planning',
#  'effective',
#  'concurrently',
#  'strong',
#  'year',
#  'bank',
#  'base',
#  'rate',
#  'rhb',
#  'bhd',
#  'rates',
#  'blr',
#  'islamic',
#  'bhds',
#  'bfr',
#  'financing',
#  'bsn',
#  '685',
#  'lending',
#  'highest',
#  'banks',
#  'financial',
#  'institutions',
#  'malaysia',
#  'lendingfinancing',
#  'end',
#  '410',
#  'malayan',
#  'house',
#  'webiste',
#  '407',
#  'bangkok',
#  '405',
#  '365',
#  '737',
#  'bhd',
#  'chinese',
#  'malays',
#  'malaysia',
#  'population',
#  'indians',
#  'politicians',
#  'police',
#  'million',
#  'companies',
#  'nonmalays',
#  'race',
#  'government',
#  'malaysian',
#  'malay',
#  'country',
#  'service',
#  'report',
#  'bumiputra',
#  'civil',
#  'new',
#  'ethnic',
#  'force',
#  'percentage',
#  'group',
#  'army',
#  'according',
#  '2015',
#  'glcs',
#  'bumiputera',
#  'cent',
#  'said',
#  'growth',
#  'outstanding',
#  'july',
#  'bnm',
#  'month',
#  'august',
#  'loan',
#  'central',
#  ...]

# %%
# Let's aggregate this list and identify the most common words along with how many routines they occur in
Counter(words).most_common()
# Out:
# [('financial', 121),
#  ('bank', 109),
#  ('said', 104),
#  ('institutions', 82),
#  ('development', 74),
#  ('financing', 65),
#  ('banks', 61),
#  ('malaysia', 59),
#  ('banking', 56),
#  ('growth', 49),
#  ('smes', 47),
#  ('business', 46),
#  ('year', 46),
#  ('negara', 43),
#  ('government', 40),
#  ('new', 37),
#  ('loans', 37),
#  ('bhd', 36),
#  ('sector', 33),
#  ('sme', 30),
#  ('credit', 29),
#  ('loan', 29),
#  ('islamic', 28),
#  ('economic', 27),
#  ('services', 26),
#  ('companies', 26),
#  ('total', 25),
#  ('finance', 24),
#  ('funds', 23),
#  ('capital', 23),
#  ('increase', 21),
#  ('small', 20),
#  ('market', 20),
#  ('private', 20),
#  ('economy', 19),
#  ('guarantee', 19),
#  ('outstanding', 19),
#  ('support', 18),
#  ('dfis', 17),
#  ('domestic', 16),
#  ('higher', 15),
#  ('central', 15),
#  ('global', 15),
#  ('continue', 15),
#  ('ensure', 15),
#  ('says', 15),
#  ('datuk', 15),
#  ('net', 14),
#  ('investment', 14),
#  ('measures', 14),
#  ('management', 14),
#  ('debt', 14),
#  ('years', 13),
#  ('lending', 13),
#  ('insurance', 13),
#  ('public', 13),
#  ('budget', 13),
#  ('fund', 13),
#  ('sectors', 13),
#  ('foreign', 13),
#  ('income', 12),
#  ('customers', 12),
#  ('activities', 12),
#  ('cgc', 12),
#  ('bnm', 12),
#  ('products', 12),
#  ('industry', 12),
#  ('continued', 12),
#  ('personal', 11),
#  ('rate', 11),
#  ('provide', 11),
#  ('expected', 11),
#  ('added', 11),
#  ('report', 11),
#  ('board', 11),
#  ('performance', 10),
#  ('month', 10),
#  ('need', 10),
#  ('scheme', 10),
#  ('malaysian', 10),
#  ('corporate', 10),
#  ('enterprises', 10),
#  ('ratio', 10),
#  ('annual', 10),
#  ('households', 10),
#  ('household', 10),
#  ('plan', 9),
#  ('help', 9),
#  ('businesses', 9),
#  ('including', 9),
#  ('firms', 9),
#  ('money', 9),
#  ('medium', 9),
#  ('greater', 9),
#  ('various', 9),
#  ('tax', 9),
#  ('mohd', 9),
#  ('strong', 9),
#  ('increased', 9),
#  ('act', 9),
#  ('fiscal', 8),
#  ('minister', 8),
#  ('end', 8),
#  ('account', 8),
#  ('deposits', 8),
#  ('risk', 8),
#  ('rates', 8),
#  ('level', 8),
#  ('expansion', 8),
#  ('include', 8),
#  ('set', 7),
#  ('lumpur', 7),
#  ('funding', 7),
#  ('package', 7),
#  ('service', 7),
#  ('access', 7),
#  ('operations', 7),
#  ('rakyat', 7),
#  ('needs', 7),
#  ('group', 7),
#  ('key', 7),
#  ('national', 7),
#  ('long', 7),
#  ('number', 7),
#  ('gross', 7),
#  ('2016', 7),
#  ('auditors', 7),
#  ('international', 7),
#  ('approved', 7),
#  ('infrastructure', 7),
#  ('assets', 7),
#  ('securities', 7),
#  ('role', 6),
#  ('dfi', 6),
#  ('pembangunan', 6),
#  ('recent', 6),
#  ('period', 6),
#  ('remain', 6),
#  ('2018', 6),
#  ('governments', 6),
#  ('million', 6),
#  ('exim', 6),
#  ('proposed', 6),
#  ('trade', 6),
#  ('chief', 6),
#  ('programme', 6),
#  ('mainly', 6),
#  ('framework', 6),
#  ('july', 6),
#  ('important', 6),
#  ('consumption', 6),
#  ('driven', 6),
#  ('oil', 6),
#  ('prices', 6),
#  ('current', 6),
#  ('initiatives', 6),
#  ('information', 6),
#  ('rose', 6),
#  ('wan', 6),
#  ('value', 6),
#  ('aob', 6),
#  ('audit', 6),
#  ('2010', 6),
#  ('click', 6),
#  ('special', 5),
#  ('billion', 5),
#  ('committee', 5),
#  ('stimulus', 5),
#  ('people', 5),
#  ('nasional', 5),
#  ('card', 5),
#  ('term', 5),
#  ('online', 5),
#  ('cooperatives', 5),
#  ('quarter', 5),
#  ('merger', 5),
#  ('mandates', 5),
#  ('high', 5),
#  ('time', 5),
#  ('focus', 5),
#  ('housing', 5),
#  ('tan', 5),
#  ('officer', 5),
#  ('partner', 5),
#  ('executive', 5),
#  ('applications', 5),
#  ('requirements', 5),
#  ('feedback', 5),
#  ('country', 5),
#  ('2015', 5),
#  ('dr', 5),
#  ('provided', 5),
#  ('relief', 5),
#  ('cimb', 5),
#  ('gdp', 5),
#  ('consumer', 5),
#  ('guidelines', 5),
#  ('local', 5),
#  ('payment', 5),
#  ('takaful', 5),
#  ('supported', 5),
#  ('spending', 5),
#  ('consumers', 5),
#  ('investors', 5),
#  ('benefit', 5),
#  ('price', 5),
#  ('plans', 5),
#  ('target', 5),
#  ('azhar', 5),
#  ('low', 5),
#  ('borrowers', 5),
#  ('areas', 4),
#  ('crisis', 4),
#  ('different', 4),
#  ('looking', 4),
#  ('liquidity', 4),
#  ('markets', 4),
#  ('ringgit', 4),
#  ('pfis', 4),
#  ('prime', 4),
#  ('months', 4),
#  ('criteria', 4),
#  ('branches', 4),
#  ('work', 4),
#  ('portfolio', 4),
#  ('2020', 4),
#  ('restructuring', 4),
#  ('given', 4),
#  ('asset', 4),
#  ('institution', 4),
#  ('property', 4),
#  ('investments', 4),
#  ('strengthen', 4),
#  ('technology', 4),
#  ('sri', 4),
#  ('entrepreneurs', 4),
#  ('grew', 4),
#  ('compared', 4),
#  ('award', 4),
#  ('sources', 4),
#  ('policy', 4),
#  ('bsn', 4),
#  ('civil', 4),
#  ('equity', 4),
#  ('available', 4),
#  ('improve', 4),
#  ('assistance', 4),
#  ('standards', 4),
#  ('pace', 4),
#  ('stable', 4),
#  ('m3', 4),
#  ('extended', 4),
#  ('regulatory', 4),
#  ('disputes', 4),
#  ('2013', 4),
#  ('resolution', 4),
#  ('crude', 4),
#  ('director', 4),
#  ('countrys', 4),
#  ('programmes', 4),
#  ('overseas', 4),
#  ('result', 4),
#  ('collateral', 4),
#  ('31', 4),
#  ('remained', 4),
#  ('place', 4),
#  ('launch', 4),
#  ('segment', 4),
#  ('commercial', 4),
#  ('mbsb', 4),
#  ('product', 4),
#  ('issues', 4),
#  ('accounts', 4),
#  ('players', 4),
#  ('guaranteed', 4),
#  ('2007', 4),
#  ('implemented', 4),
#  ('mandate', 3),
#  ('noted', 3),
#  ('play', 3),
#  ('share', 3),
#  ('reduced', 3),
#  ('applied', 3),
#  ('expand', 3),
#  ('commitment', 3),
#  ('participants', 3),
#  ('facility', 3),
#  ('contact', 3),
#  ('schemes', 3),
#  ('conditions', 3),
#  ('ecosystem', 3),
#  ('glcs', 3),
#  ('major', 3),
#  ('epf', 3),
#  ('repayment', 3),
#  ('repayments', 3),
#  ('meet', 3),
#  ('monthly', 3),
#  ('april', 3),
#  ('providers', 3),
#  ('open', 3),
#  ('members', 3),
#  ('operators', 3),
#  ('grow', 3),
#  ('deficit', 3),
#  ('rating', 3),
#  ('danajamin', 3),
#  ('phase', 3),
#  ('proposal', 3),
#  ('working', 3),
#  ('corp', 3),
#  ('profit', 3),
#  ('cost', 3),
#  ('sustainable', 3),
#  ('affected', 3),
#  ('proposals', 3),
#  ('base', 3),
#  ('digital', 3),
#  ('boost', 3),
#  ('incentives', 3),
#  ('ceo', 3),
#  ('second', 3),
#  ('kuala', 3),
#  ('lim', 3),
#  ('agencies', 3),
#  ('export', 3),
#  ('balance', 3),
#  ('bumiputera', 3),
#  ('awards', 3),
#  ('providing', 3),
#  ('fis', 3),
#  ('institutional', 3),
#  ('conventional', 3),
#  ('costs', 3),
#  ('petaling', 3),
#  ('collaboration', 3),
#  ('statement', 3),
#  ('governance', 3),
#  ('rhb', 3),
#  ('chinese', 3),
#  ('bumiputra', 3),
#  ('respectively', 3),
#  ('application', 3),
#  ('building', 3),
#  ('listed', 3),
#  ('awareness', 3),
#  ('flood', 3),
#  ('maximum', 3),
#  ('come', 3),
#  ('protection', 3),
#  ('muhammad', 3),
#  ('exchange', 3),
#  ('lot', 3),
#  ('january', 3),
#  ('tier', 3),
#  ('decline', 3),
#  ('november', 3),
#  ('amid', 3),
#  ('recorded', 3),
#  ('negaras', 3),
#  ('charge', 3),
#  ('fee', 3),
#  ('did', 3),
#  ('dispute', 3),
#  ('june', 3),
#  ('accounting', 3),
#  ('alternative', 3),
#  ('targets', 3),
#  ('seri', 3),
#  ('barrel', 3),
#  ('malaysias', 3),
#  ('enforcement', 3),
#  ('countries', 3),
#  ('deputy', 3),
#  ('ahmad', 3),
#  ('capacity', 3),
#  ('centre', 3),
#  ('launched', 3),
#  ('meeting', 3),
#  ('asia', 3),
#  ('china', 3),
#  ('applicants', 3),
#  ('disbursed', 3),
#  ('proper', 3),
#  ('dfia', 3),
#  ('2014', 3),
#  ('member', 3),
#  ('strategic', 3),
#  ('latest', 3),
#  ('stability', 3),
#  ('npl', 3),
#  ('auditor', 3),
#  ('hasyudeen', 3),
#  ('change', 3),
#  ('12', 3),
#  ('leading', 3),
#  ('look', 3),
#  ('cards', 3),
#  ('bureau', 3),
#  ('demand', 3),
#  ('deposit', 3),
#  ('pidm', 3),
#  ('depositors', 3),
#  ('charts', 3),
#  ('company', 3),
#  ('source', 3),
#  ('kamal', 3),
#  ('construction', 3),
#  ('mandated', 2),
#  ('dividend', 2),
#  ('allowance', 2),
#  ('lower', 2),
#  ('executing', 2),
#  ('remains', 2),
#  ('ppp', 2),
#  ('half', 2),
#  ('york', 2),
#  ('clients', 2),
#  ('know', 2),
#  ('borrow', 2),
#  ('dollar', 2),
#  ('onshore', 2),
#  ('repo', 2),
#  ('sufficient', 2),
#  ('acknowledged', 2),
#  ('discussed', 2),
#  ('agreements', 2),
#  ('preemptively', 2),
#  ('apply', 2),
#  ('annum', 2),
#  ('sixmonth', 2),
#  ('power', 2),
#  ('offer', 2),
#  ('deferment', 2),
#  ('loanfinancing', 2),
#  ('borrowerscustomers', 2),
#  ('loansfinancing', 2),
#  ('deferred', 2),
#  ('qualify', 2),
#  ('yes', 2),
#  ('essential', 2),
#  ('containment', 2),
#  ('operating', 2),
#  ('atms', 2),
#  ('cash', 2),
#  ('refer', 2),
#  ('remittance', 2),
#  ('advised', 2),
#  ('cooperative', 2),
#  ('home', 2),
#  ('commodity', 2),
#  ('economist', 2),
#  ('manokaran', 2),
#  ('bpmb', 2),
#  ('ministry', 2),
#  ('analyst', 2),
#  ('negotiations', 2),
#  ('green', 2),
#  ('groups', 2),
#  ('noripah', 2),
#  ('largest', 2),
#  ('nations', 2),
#  ('likely', 2),
#  ('spur', 2),
#  ('entity', 2),
#  ('develop', 2),
#  ('indicators', 2),
#  ('2019', 2),
#  ('merge', 2),
#  ('relevant', 2),
#  ('competition', 2),
#  ('assist', 2),
#  ('sales', 2),
#  ('cedar', 2),
#  ('previously', 2),
#  ('directors', 2),
#  ('efforts', 2),
#  ('especially', 2),
#  ('fi', 2),
#  ('category', 2),
#  ('attract', 2),
#  ('professionals', 2),
#  ('professional', 2),
#  ('main', 2),
#  ('reported', 2),
#  ('average', 2),
#  ('impact', 2),
#  ('measurement', 2),
#  ('world', 2),
#  ('measure', 2),
#  ('supervisory', 2),
#  ('chartered', 2),
#  ('zamree', 2),
#  ('senior', 2),
#  ('ability', 2),
#  ('oversight', 2),
#  ('issued', 2),
#  ('effective', 2),
#  ('house', 2),
#  ('politicians', 2),
#  ('percentage', 2),
#  ('cent', 2),
#  ('rising', 2),
#  ('shamsiah', 2),
#  ('positive', 2),
#  ('proportionality', 2),
#  ('zero', 2),
#  ('society', 2),
#  ('contribute', 2),
#  ('good', 2),
#  ('record', 2),
#  ('structure', 2),
#  ('officers', 2),
#  ('organisations', 2),
#  ('like', 2),
#  ('line', 2),
#  ('adfiap', 2),
#  ('floods', 2),
#  ('held', 2),
#  ('45', 2),
#  ('allocation', 2),
#  ('leverage', 2),
#  ('korean', 2),
#  ('strength', 2),
#  ('governor', 2),
#  ('societies', 2),
#  ('want', 2),
#  ('relating', 2),
#  ('attention', 2),
#  ('54', 2),
#  ('broad', 2),
#  ('manufacturing', 2),
#  ('december', 2),
#  ('slightly', 2),
#  ('purchase', 2),
#  ('issuances', 2),
#  ('moderation', 2),
#  ('draft', 2),
#  ('licensed', 2),
#  ('overall', 2),
#  ('residential', 2),
#  ('registered', 2),
#  ('pay', 2),
#  ('charges', 2),
#  ('make', 2),
#  ('ombudsman', 2),
#  ('bad', 2),
#  ('fraud', 2),
#  ('1mdb', 2),
#  ('say', 2),
#  ('creative', 2),
#  ('involved', 2),
#  ('commission', 2),
#  ('firm', 2),
#  ('cgcs', 2),
#  ('guarantees', 2),
#  ('contributions', 2),
#  ('venture', 2),
#  ('crowdfunding', 2),
#  ('expenditure', 2),
#  ('revenue', 2),
#  ('gap', 2),
#  ('tppa', 2),
#  ('rm6bil', 2),
#  ('research', 2),
#  ('wee', 2),
#  ('ministers', 2),
#  ('reduce', 2),
#  ('workers', 2),
#  ('putrajaya', 2),
#  ('dec', 2),
#  ('nation', 2),
#  ('challenges', 2),
#  ('najib', 2),
#  ('study', 2),
#  ('east', 2),
#  ('regulations', 2),
#  ('process', 2),
#  ('issuers', 2),
#  ('decision', 2),
#  ('import', 2),
#  ('chua', 2),
#  ('asian', 2),
#  ('following', 2),
#  ('association', 2),
#  ('hong', 2),
#  ('particularly', 2),
#  ('direct', 2),
#  ('consultation', 2),
#  ('appointment', 2),
#  ('subsidiaries', 2),
#  ('received', 2),
#  ('submitted', 2),
#  ('cooperation', 2),
#  ('fmm', 2),
#  ('region', 2),
#  ('promote', 2),
#  ('sukuk', 2),
#  ('accounted', 2),
#  ('bursa', 2),
#  ('basis', 2),
#  ('wong', 2),
#  ('increasing', 2),
#  ('bonds', 2),
#  ('nbfis', 2),
#  ('effect', 2),
#  ('fsa', 2),
#  ('march', 2),
#  ('2012', 2),
#  ('entities', 2),
#  ('agricultural', 2),
#  ('practices', 2),
#  ('worth', 2),
#  ('opening', 2),
#  ('concern', 2),
#  ('uhy', 2),
#  ('reprimand', 2),
#  ('believe', 2),
#  ('pie', 2),
#  ('statements', 2),
#  ('matter', 2),
#  ('tee', 2),
#  ('aobs', 2),
#  ('pies', 2),
#  ('sc', 2),
#  ('nik', 2),
#  ('engagement', 2),
#  ('individual', 2),
#  ('environment', 2),
#  ('nonbank', 2),
#  ('united', 2),
#  ('past', 2),
#  ('ratings', 2),
#  ('registration', 2),
#  ('inspections', 2),
#  ('tenure', 2),
#  ('retail', 2),
#  ('stake', 2),
#  ('amounted', 2),
#  ('balances', 2),
#  ('licences', 2),
#  ('potential', 2),
#  ('debts', 2),
#  ('assisting', 2),
#  ('cases', 2),
#  ('pension', 2),
#  ('used', 2),
#  ('investor', 2),
#  ('council', 2),
#  ('fmb', 2),
#  ('micro', 2),
#  ('tay', 2),
#  ('microfinancing', 2),
#  ('npls', 2),
#  ('confidence', 2),
#  ('2008', 2),
#  ('managing', 2),
#  ('embarked', 2),
#  ('faced', 2),
#  ('capability', 2),
#  ('face', 2),
#  ('fully', 2),
#  ('currency', 2),
#  ('2006', 2),
#  ('mifc', 2),
#  ('indonesia', 2),
#  ('food', 2),
#  ('2005', 2),
#  ('operate', 2),
#  ('marketing', 2),
#  ('abdullah', 2),
#  ('logo', 2),
#  ('improved', 2),
#  ('partnership', 2),
#  ('improving', 2),
#  ('eoncap', 2),
#  ('locally', 2),
#  ('projected', 2),
#  ('eogf', 2),
#  ('rm1bil', 2),
#  ('aimed', 2),
#  ('ali', 2),
#  ('abdul', 2),
#  ('address', 2),
#  ('2004', 2),
#  ('zeti', 2),
#  ('industrial', 2),
#  ('industri', 2),
#  ('othman', 2),
#  ('industries', 2),
#  ('projects', 2),
#  ('facilitate', 2),
#  ('terms', 1),
#  ('anuar', 1),
#  ('khairil', 1),
#  ('deliverables', 1),
#  ('notes', 1),
#  ('fy19', 1),
#  ('lowest', 1),
#  ('rm380mil', 1),
#  ('gains', 1),
#  ('notably', 1),
#  ('redeemable', 1),
#  ('fy2019', 1),
#  ('rm25bil', 1),
#  ('caraballo', 1),
#  ('nail', 1),
#  ('salon', 1),
#  ('ago', 1),
#  ('rent', 1),
#  ('estimates', 1),
#  ('usual', 1),
#  ('nearly', 1),
#  ('technicians', 1),
#  ('cleaning', 1),
#  ('minority', 1),
#  ('program', 1),
#  ('fed', 1),
#  ('paycheck', 1),
#  ('washington', 1),
#  ('announce', 1),
#  ('allows', 1),
#  ('thursday', 1),
#  ('rules', 1),
#  ('shortly', 1),
#  ('broader', 1),
#  ('deposittaking', 1),
#  ('federal', 1),
#  ('use', 1),
#  ('array', 1),
#  ('reserve', 1),
#  ('administrations', 1),
#  ('currently', 1),
#  ('moratorium', 1),
#  ('imsme', 1),
#  ('visit', 1),
#  ('srf', 1),
#  ('bizmulai', 1),
#  ('existing', 1),
#  ('imsmecommy', 1),
#  ('bizwanitai', 1),
#  ('supporting', 1),
#  ('ongoing', 1),
#  ('nexus', 1),
#  ('muhyiddin', 1),
#  ('powerful', 1),
#  ('political', 1),
#  ('perikatan', 1),
#  ('mara', 1),
#  ('politicalbusiness', 1),
#  ('automatically', 1),
#  ('individuals', 1),
#  ('accrue', 1),
#  ('wish', 1),
#  ('mco', 1),
#  ('epayment', 1),
#  ('check', 1),
#  ('terminals', 1),
#  ('counter', 1),
#  ('uninterrupted', 1),
#  ('rosman', 1),
#  ('coming', 1),
#  ('4q19', 1),
#  ('expects', 1),
#  ('outbreak', 1),
#  ('3q19', 1),
#  ('yoy', 1),
#  ('1q20', 1),
#  ('supply', 1),
#  ('steering', 1),
#  ('comittee', 1),
#  ('achieve', 1),
#  ('commence', 1),
#  ('bpmbphase', 1),
#  ('comprising', 1),
#  ('entitythere', 1),
#  ('profits', 1),
#  ('cir', 1),
#  ('pbtz', 1),
#  ('encouraging', 1),
#  ('contributed', 1),
#  ('treasury', 1),
#  ('20', 1),
#  ('friday', 1),
#  ('khazanah', 1),
#  ('reduction', 1),
#  ('surprise', 1),
#  ('toll', 1),
#  ('far', 1),
#  ('solar', 1),
#  ('turn', 1),
#  ('synergies', 1),
#  ('ltat', 1),
#  ('welcome', 1),
#  ('adoption', 1),
#  ('allocate', 1),
#  ('malaysians', 1),
#  ('speaker', 1),
#  ('sir', 1),
#  ('exportimport', 1),
#  ('enterprise', 1),
#  ('single', 1),
#  ('berhad', 1),
#  ('twostage', 1),
#  ('star', 1),
#  ('resources', 1),
#  ('soba', 1),
#  ('eye', 1),
#  ('sdn', 1),
#  ('senhengs', 1),
#  ('teh', 1),
#  ('learning', 1),
#  ('addaem', 1),
#  ('transformation', 1),
#  ('aria', 1),
#  ('putera', 1),
#  ('targeted', 1),
#  ('conducted', 1),
#  ('based', 1),
#  ('fy18', 1),
#  ('13', 1),
#  ('rakyats', 1),
#  ('amounting', 1),
#  ('recognises', 1),
#  ('appreciation', 1),
#  ('receive', 1),
#  ('ambank', 1),
#  ('corporation', 1),
#  ('testament', 1),
#  ('badlisyah', 1),
#  ('growing', 1),
#  ('vbi', 1),
#  ('ciif', 1),
#  ('size', 1),
#  ('intermediation', 1),
#  ('11', 1),
#  ('body', 1),
#  ('respondents', 1),
#  ('survey', 1),
#  ('insufficient', 1),
#  ('22', 1),
#  ('documentation', 1),
#  ('rejection', 1),
#  ('necessary', 1),
#  ('aims', 1),
#  ('effectively', 1),
#  ('enhanced', 1),
#  ('optimising', 1),
#  ('women', 1),
#  ('standard', 1),
#  ('tranches', 1),
#  ('pg', 1),
#  ('scm', 1),
#  ('abrar', 1),
#  ('amiruddin', 1),
#  ('saadiq', 1),
#  ('anniversary', 1),
#  ('inclusion', 1),
#  ('outsourcing', 1),
#  ('document', 1),
#  ('arrangements', 1),
#  ('obtain', 1),
#  ('planning', 1),
#  ('concurrently', 1),
#  ('blr', 1),
#  ('bhds', 1),
#  ('bfr', 1),
#  ('685', 1),
#  ('highest', 1),
#  ('lendingfinancing', 1),
#  ('410', 1),
#  ('malayan', 1),
#  ('webiste', 1),
#  ('407', 1),
#  ('bangkok', 1),
#  ('405', 1),
#  ('365', 1),
#  ('737', 1),
#  ('malays', 1),
#  ('population', 1),
#  ('indians', 1),
#  ('police', 1),
#  ('nonmalays', 1),
#  ('race', 1),
#  ('malay', 1),
#  ('ethnic', 1),
#  ('force', 1),
#  ('army', 1),
#  ('according', 1),
#  ('august', 1),
#  ('threemonth', 1),
#  ('ringgits', 1),
#  ('basel', 1),
#  ('approvals', 1),
#  ('outflows', 1),
#  ('landscape', 1),
#  ('success', 1),
#  ('deliver', 1),
#  ('maturity', 1),
#  ('diversify', 1),
#  ('health', 1),
#  ('foundation', 1),
#  ('grounded', 1),
#  ('longterm', 1),
#  ('dependent', 1),
#  ('externalities', 1),
#  ('maybank', 1),
#  ('demonstrated', 1),
#  ('customer', 1),
#  ('hassan', 1),
#  ('exemplary', 1),
#  ('track', 1),
#  ('presented', 1),
#  ('ownership', 1),
#  ('reforms', 1),
#  ('serve', 1),
#  ('reform', 1),
#  ('complex', 1),
#  ('marina', 1),
#  ('97', 1),
#  ('assisted', 1),
#  ('matters', 1),
#  ('ttt', 1),
#  ('respective', 1),
#  ('organisation', 1),
#  ('imsmezamree', 1),
#  ('1976', 1),
#  ('selected', 1),
#  ('ishak', 1),
#  ('recognition', 1),
#  ('express', 1),
#  ('founded', 1),
#  ('disaster', 1),
#  ('districts', 1),
#  ('60', 1),
#  ('10', 1),
#  ('retirement', 1),
#  ('44the', 1),
#  ('ment', 1),
#  ('segments', 1),
#  ('utilised', 1),
#  ('rm302bil', 1),
#  ('continuous', 1),
#  ('purposes', 1),
#  ('inflation', 1),
#  ('bitcoin', 1),
#  ('cryptocurrencies', 1),
#  ('rely', 1),
#  ('competitiveness', 1),
#  ('content', 1),
#  ('accountability', 1),
#  ('highlighted', 1),
#  ('approaches', 1),
#  ('frameworks', 1),
#  ('drive', 1),
#  ('unique', 1),
#  ('socioeconomic', 1),
#  ('reflect', 1),
#  ('reflective', 1),
#  ('symposium', 1),
#  ('anti', 1),
#  ('issue', 1),
#  ('speaking', 1),
#  ('form', 1),
#  ('february', 1),
#  ('extension', 1),
#  ('motor', 1),
#  ('2017', 1),
#  ('transactions', 1),
#  ('volatility', 1),
#  ('3q', 1),
#  ('q4', 1),
#  ('expanded', 1),
#  ('economies', 1),
#  ('rm299bil', 1),
#  ('rm293bil', 1),
#  ('monthoutstanding', 1),
#  ('monthnet', 1),
#  ('tuesday', 1),
#  ('written', 1),
#  ('expectations', 1),
#  ('exposure', 1),
#  ('exceptional', 1),
#  ('prescribed', 1),
#  ('uncertainty', 1),
#  ('concentration', 1),
#  ('october', 1),
#  ('29', 1),
#  ('rm69il', 1),
#  ('psc', 1),
#  ('ofs', 1),
#  ('paying', 1),
#  ('airports', 1),
#  ('travellers', 1),
#  ('mavcom', 1),
#  ('rm1', 1),
#  ('security', 1),
#  ('airport', 1),
#  ('upgrade', 1),
#  ('independent', 1),
#  ...]

# %%
# If more than half of the news have it as a top word, exclude it from the list
add_stop_words = [word for word, count in Counter(words).most_common() if count > 6]
add_stop_words
# Out:
# ['financial',
#  'bank',
#  'said',
#  'institutions',
#  'development',
#  'financing',
#  'banks',
#  'malaysia',
#  'banking',
#  'growth',
#  'smes',
#  'business',
#  'year',
#  'negara',
#  'government',
#  'new',
#  'loans',
#  'bhd',
#  'sector',
#  'sme',
#  'credit',
#  'loan',
#  'islamic',
#  'economic',
#  'services',
#  'companies',
#  'total',
#  'finance',
#  'funds',
#  'capital',
#  'increase',
#  'small',
#  'market',
#  'private',
#  'economy',
#  'guarantee',
#  'outstanding',
#  'support',
#  'dfis',
#  'domestic',
#  'higher',
#  'central',
#  'global',
#  'continue',
#  'ensure',
#  'says',
#  'datuk',
#  'net',
#  'investment',
#  'measures',
#  'management',
#  'debt',
#  'years',
#  'lending',
#  'insurance',
#  'public',
#  'budget',
#  'fund',
#  'sectors',
#  'foreign',
#  'income',
#  'customers',
#  'activities',
#  'cgc',
#  'bnm',
#  'products',
#  'industry',
#  'continued',
#  'personal',
#  'rate',
#  'provide',
#  'expected',
#  'added',
#  'report',
#  'board',
#  'performance',
#  'month',
#  'need',
#  'scheme',
#  'malaysian',
#  'corporate',
#  'enterprises',
#  'ratio',
#  'annual',
#  'households',
#  'household',
#  'plan',
#  'help',
#  'businesses',
#  'including',
#  'firms',
#  'money',
#  'medium',
#  'greater',
#  'various',
#  'tax',
#  'mohd',
#  'strong',
#  'increased',
#  'act',
#  'fiscal',
#  'minister',
#  'end',
#  'account',
#  'deposits',
#  'risk',
#  'rates',
#  'level',
#  'expansion',
#  'include',
#  'set',
#  'lumpur',
#  'funding',
#  'package',
#  'service',
#  'access',
#  'operations',
#  'rakyat',
#  'needs',
#  'group',
#  'key',
#  'national',
#  'long',
#  'number',
#  'gross',
#  '2016',
#  'auditors',
#  'international',
#  'approved',
#  'infrastructure',
#  'assets',
#  'securities']

# %%
# Let's update our document-term matrix with the new list of stop words
from sklearn.feature_extraction import text 
from sklearn.feature_extraction.text import CountVectorizer

# Read in cleaned data
data_clean = pd.read_pickle('data_clean.pkl')

# Add new stop words
stop_words = text.ENGLISH_STOP_WORDS.union(add_stop_words)

# Recreate document-term matrix
cv = CountVectorizer(stop_words=stop_words)
data_cv = cv.fit_transform(data_clean.transcript)
data_stop = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
data_stop.index = data_clean.index

# Pickle it for later use
import pickle
pickle.dump(cv, open("cv_stop.pkl", "wb"))
data_stop.to_pickle("dtm_stop.pkl")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-86051220cb66> in <module>
#      11 # Recreate document-term matrix
#      12 cv = CountVectorizer(stop_words=stop_words)
# ---> 13 data_cv = cv.fit_transform(data_clean.transcript)
#      14 data_stop = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
#      15 data_stop.index = data_clean.index
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'transcript'

# %%
# Let's make some word clouds!
# Terminal / Anaconda Prompt: conda install -c conda-forge wordcloud
from wordcloud import WordCloud

wc = WordCloud(stopwords=stop_words, background_color="white", colormap="Dark2",
               max_font_size=150, random_state=42)

# %%
# Reset the output dimensions
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [16, 6]

full_names = ['Ali Wong', 'Anthony Jeselnik', 'Bill Burr', 'Bo Burnham', 'Dave Chappelle', 'Hasan Minhaj',
              'Jim Jefferies', 'Joe Rogan', 'John Mulaney', 'Louis C.K.', 'Mike Birbiglia', 'Ricky Gervais']

# Create subplots for each comedian
for index, comedian in enumerate(data.columns):
    wc.generate(data_clean.transcript[comedian])
    
    plt.subplot(3, 4, index+1)
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.title(full_names[index])
    
plt.show()

# %% [markdown]
# ### Findings

# %% [markdown]
# * Ali Wong says the s-word a lot and talks about her husband. I guess that's funny to me.
# * A lot of people use the F-word. Let's dig into that later.

# %% [markdown]
# ## Number of Words

# %% [markdown]
# ### Analysis

# %%
# Find the number of unique words that each comedian uses

# Identify the non-zero items in the document-term matrix, meaning that the word occurs at least once
unique_list = []
for comedian in data.columns:
    uniques = data[comedian].to_numpy().nonzero()[0].size
    unique_list.append(uniques)

# Create a new dataframe that contains this unique word count
data_words = pd.DataFrame(list(zip(full_names, unique_list)), columns=['comedian', 'unique_words'])
data_unique_sort = data_words.sort_values(by='unique_words')
data_unique_sort

# %%
# Calculate the words per minute of each comedian

# Find the total number of words that a comedian uses
total_list = []
for comedian in data.columns:
    totals = sum(data[comedian])
    total_list.append(totals)
    
# Comedy special run times from IMDB, in minutes
run_times = [60, 59, 80, 60, 67, 73, 77, 63, 62, 58, 76, 79]

# Let's add some columns to our dataframe
data_words['total_words'] = total_list
data_words['run_times'] = run_times
data_words['words_per_minute'] = data_words['total_words'] / data_words['run_times']

# Sort the dataframe by words per minute to see who talks the slowest and fastest
data_wpm_sort = data_words.sort_values(by='words_per_minute')
data_wpm_sort

# %%
# Let's plot our findings
import numpy as np

y_pos = np.arange(len(data_words))

plt.subplot(1, 2, 1)
plt.barh(y_pos, data_unique_sort.unique_words, align='center')
plt.yticks(y_pos, data_unique_sort.comedian)
plt.title('Number of Unique Words', fontsize=20)

plt.subplot(1, 2, 2)
plt.barh(y_pos, data_wpm_sort.words_per_minute, align='center')
plt.yticks(y_pos, data_wpm_sort.comedian)
plt.title('Number of Words Per Minute', fontsize=20)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Findings

# %% [markdown]
# * **Vocabulary**
#    * Ricky Gervais (British comedy) and Bill Burr (podcast host) use a lot of words in their comedy
#    * Louis C.K. (self-depricating comedy) and Anthony Jeselnik (dark humor) have a smaller vocabulary
#
#
# * **Talking Speed**
#    * Joe Rogan (blue comedy) and Bill Burr (podcast host) talk fast
#    * Bo Burnham (musical comedy) and Anthony Jeselnik (dark humor) talk slow
#
# Ali Wong is somewhere in the middle in both cases. Nothing too interesting here.

# %% [markdown]
# ## Amount of Profanity

# %% [markdown]
# ### Analysis

# %%
# Earlier I said we'd revisit profanity. Let's take a look at the most common words again.
Counter(words).most_common()

# %%
# Let's isolate just these bad words
data_bad_words = data.transpose()[['fucking', 'fuck', 'shit']]
data_profanity = pd.concat([data_bad_words.fucking + data_bad_words.fuck, data_bad_words.shit], axis=1)
data_profanity.columns = ['f_word', 's_word']
data_profanity

# %%
# Let's create a scatter plot of our findings
plt.rcParams['figure.figsize'] = [10, 8]

for i, comedian in enumerate(data_profanity.index):
    x = data_profanity.f_word.loc[comedian]
    y = data_profanity.s_word.loc[comedian]
    plt.scatter(x, y, color='blue')
    plt.text(x+1.5, y+0.5, full_names[i], fontsize=10)
    plt.xlim(-5, 155) 
    
plt.title('Number of Bad Words Used in Routine', fontsize=20)
plt.xlabel('Number of F Bombs', fontsize=15)
plt.ylabel('Number of S Words', fontsize=15)

plt.show()

# %% [markdown]
# ### Findings

# %% [markdown]
# * **Averaging 2 F-Bombs Per Minute!** - I don't like too much swearing, especially the f-word, which is probably why I've never heard of Bill Bur, Joe Rogan and Jim Jefferies.
# * **Clean Humor** - It looks like profanity might be a good predictor of the type of comedy I like. Besides Ali Wong, my two other favorite comedians in this group are John Mulaney and Mike Birbiglia.

# %% [markdown]
# ## Side Note

# %% [markdown]
# What was our goal for the EDA portion of our journey? **To be able to take an initial look at our data and see if the results of some basic analysis made sense.**
#
# My conclusion - yes, it does, for a first pass. There are definitely some things that could be better cleaned up, such as adding more stop words or including bi-grams. But we can save that for another day. The results, especially the profanity findings, are interesting and make general sense, so we're going to move on.
#
# As a reminder, the data science process is an interative one. It's better to see some non-perfect but acceptable results to help you quickly decide whether your project is a dud or not, instead of having analysis paralysis and never delivering anything.
#
# **Alice's data science (and life) motto: Let go of perfectionism!**

# %% [markdown]
# ## Additional Exercises

# %% [markdown]
# 1. What other word counts do you think would be interesting to compare instead of the f-word and s-word? Create a scatter plot comparing them.
